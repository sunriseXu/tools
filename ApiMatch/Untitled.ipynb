# %%
# %load findAPI-ipy.py
import os
import sys
# pwd = os.path.dirname(os.path.realpath(__file__))
pwd = os.getcwd()
ppwd = os.path.dirname(pwd)
sys.path.append(ppwd)
from modules import FileUtils
from modules import CollectionUtils

from modules import RexUtils
from modules import AdbUtils
from modules import ApkUtils
from modules.FileUtils import EasyDir
from modules import InteractUtils
from modules import ThreadUtils
import os
import shutil
import random
import logging
import sys
import time
from datetime import datetime
import argparse 
from modules import InteractUtils
import Levenshtein
import random

class Method:
    def __init__(self, modifier, methodName, params, retType, constStrList,classDict,invokeList,callers):
        #修饰符，列表
        self.modifier = modifier
        #方法名，字符串
        self.methodName = methodName
        #参数，列表
        self.params = params
        #返回值，字符串
        self.retType = retType
        #常量字符串，列表
        self.constStrList = constStrList
        #类,类字典
        self.classDict = classDict
        #调用的java/android 方法,字符串列表，android/java/org
        self.invokeList = invokeList
        #调用的自定义方法，列表？表示方法的对象
        #调用这个方法的其他方法 列表 表示方法的对象
        self.callers = callers
        #方法内部的控制流图？图的表示 关键部分
        #方法内部的数据流图 图的表示 关键部分
        #这个方法出发的函数调用图 图的表示 关键部分



## 0层 简单的判断和字符串操作 简单的容器操作
def isBasicType(className):
    '''
    判断一个类是否是基本类型
    返回布尔值
    '''
    className = className.strip('[]')
    if className=='int' or className=='boolean' or className=='byte'\
        or className=='short' or className=='char' or className=='long'\
            or className=='float' or className=='double' or className=='void':
            return True
    else:
        return False
def IsSysClazzOrDeObfuscated(className, DeObfuscatedClazzSet):
    '''
    判断一个类是否是系统api
    返回布尔值
    '''
    if className in DeObfuscatedClazzSet or className.startswith('android.')\
         or className.startswith('java.') \
             or className.startswith('javax.') or isBasicType(className):
            return True
    else:
        return False
def isCostomerClazz(clazz):
    '''
    这里判断是否是app自定的方法，即非系统方法，由于发现app会对androidx，com.google包进行混淆
    '''
    if clazz.startswith('android.') or clazz.startswith('androidx.')\
            or clazz.startswith('com.google.') or clazz.startswith('com.facebook.')\
                or clazz.startswith('org.') or clazz.startswith('okhttp3.')\
                    or clazz.startswith('kotlin.') or clazz.startswith('addon.')\
                        or clazz.startswith('com.airbnb') or clazz.startswith('kotlinx.')\
                        	or clazz.startswith('net.') or clazz.startswith('kotlinx.')\
                        		or clazz.startswith('javax.') or clazz.startswith('com.ad'):
                                return False
    else:
        return True
### 0层 把参数列表转换成认为可读的字符串形式
def list2Str(myList):
    res = '('
    if len(myList) == 0:
        return '()'
    for idx in range(len(myList)):
        if idx != len(myList)-1:
            res += myList[idx]+','
        else:
            res += myList[idx]+')'
    return res
def calTopN(myList,N,newElem):
    for idx in range(0,N):
        if newElem[1]<myList[idx][1]:
            myInsert(myList,idx,newElem,N)
            break
def myInsert(myList,idx,value,N):
    assert(idx>=0 and idx<N)
    for i in range(N-1,-1,-1):
        if i == idx:
            break
        myList[i] = myList[i-1]
    myList[idx] = value
    return myList
### 0层 判断列表元素符合条件的个数
def sysClassNum(params):
    '''
    统计参数中包含的系统参数的数量，用于筛选一定长度的包含系统类的参数
    '''
    count = 0
    for item in params:
        if item.startswith('java.') or item.startswith('android.')\
            or item.startswith('javax.') or item.startswith('androidx.'):
            count+=1
    return count
def concatList(myList, sperator='##'):
    return sperator.join(myList)
def splitFullMethodName(item):
    '''
    基础重要方法，对完整方法名进行分离成 类名 方法名 参数
    输入：
        item：完整方法名
    输出：
        方法名的分解
    '''
    tmp = item.strip().split('(')
    fullName = tmp[0]
    params = '('+tmp[1]
    fullNameList = fullName.split('.')
    clazz = fullNameList[0:-1]
    clazzName = '.'.join(clazz)
    methodName = fullNameList[-1].strip()
    methodIdentifier = methodName+params
    return clazzName, methodName, params,methodIdentifier
## 算法层 简单算法
def jaccard_similarity(list1, list2):
    s1 = set(list1)
    s2 = set(list2)
    if len(s1.union(s2)) == 0:
        return 1.0
    return len(s1.intersection(s2)) / len(s1.union(s2))
### 路径操作，在原路径中，对文件名添加后缀
def addExt2Path(oriPath, myExt):
    '''
    路径操作，在原路径中，对文件名添加后缀
    输入：
        oriPath：原始路径
        myExt：文件需要添加的后缀
    输出：
        添加完后缀的文件路径
    '''
    targetDir = os.path.dirname(oriPath)
    targetName = os.path.basename(oriPath)
    bsName = os.path.splitext(targetName)[0]
    if len(os.path.splitext(targetName))>1:
        ext = os.path.splitext(targetName)[1]
    else:
        ext = ''
    bsName = bsName+myExt+ext
    destPath = os.path.join(targetDir,bsName)
    return destPath

### 1层 统计类
###1 层 对字典中的字段进行简单的统计
def getCalleeLen(methodDict):
    '''
    参数是代表方法的字典，返回这个方法invoke callee序列的长度
    '''
    invokeList = methodDict['invoke']
    return len(invokeList)
def tongjilei(packageDict):
    '''
    统计这个包下面类的数量，方法的数量，字段的数量
    '''
    clazzCount = len(packageDict)
    methodCount = 0
    fieldCount = 0
    for clazz in packageDict:
        classDict = packageDict[clazz]
        methodDictList = classDict['methods']
        methodCount+=len(methodDictList)
        fields = classDict['fields']
        fieldCount+= len(fields['staticFields'])
        fieldCount+= len(fields['instanceFields'])
    print("clazzCount:{}".format(clazzCount))
    print("methodCount:{}".format(methodCount))
    print("fieldCount:{}".format(fieldCount))
def sysApiNum(invokeList):
    '''
    统计invokelist中包含的系统api的数量，用于筛选一定长度的syscallee函数
    '''
    count = 0
    for invokeDict in invokeList:
        className = invokeDict['className'][0]
        if className.startswith('java.') or className.startswith('android.')\
            or className.startswith('javax.') or className.startswith('androidx.'):
            count+=1
    return count

### 对字典字段的简单查询
def getCaller(basePackageDict, fullName):
    '''
    打印一个函数所有的caller信息
    输入：
        basePackageDict：app包
        fullName：函数的完整签名
    输出：
        caller信息
    '''
    className, _, _, methodIdentifier = splitFullMethodName(fullName)
    classDict = getClass(basePackageDict, className)
    res = ''
    if not classDict:
        return res
    methodDict = getMethod(classDict,methodIdentifier)
    if 'caller' in methodDict:
        callers = methodDict['caller']
        print(callers)
    else:
        print("no caller found")

### 查询类 返回类字典
def getClass(packageDict, className):
    if className in packageDict:
        return packageDict[className]
    return {}

### 查询方法 返回方法字典
def getMethod(classDict,methodIdentifier):
    '''
    在类字典中根据方法签名获取方法字典
    输入：
        classDict：类字典
        methodIdentifier：方法签名 去类
    输出：
        方法字典
    '''
    methodDictList = classDict['methods']
    if methodIdentifier in methodDictList:
        return methodDictList[methodIdentifier]
    else:
        print("no method found in this classDict! {}".format(methodIdentifier))
        return {}

### 通过callee长度和参数长度 筛选出符合条件的方法列表 
def SelectAPI(packageDict, paramMin=2, sysParmMin=2, calleeMin=10, sysApiRotio=0.4):
    '''
    从app包中筛选出包含一定参数、callee符合指定长度的方法列表
    返回合格的方法列表
    '''
    resList = []
    for clazz in packageDict:
        if not isCostomerClazz(clazz):
            continue
        classDict = packageDict[clazz]
        methodDictList = classDict['methods']
        for methodIdentifer in methodDictList:
            #取出这个类中的所有方法
            key = "{}.{}".format(clazz, methodIdentifer)
            methodDict = methodDictList[methodIdentifer]
            params = methodDict['methodParams']
            invokeList = methodDict['invoke']
            if len(params)>paramMin and sysApiNum(invokeList)>=5:
                resList.append(key)
    return resList

### 打印类中所有方法的签名 简单的字典查询
def printClazzMethodIdenti(packageDict,clazz):
    classDict = getClass(packageDict,clazz)
    methodDictList = classDict['methods']
    identifierList = methodDictList.keys()
    InteractUtils.showList(identifierList)
    return identifierList
#列举出每一个类中的常量字符串
def getClazzConstStr(packageDict,clazz):
    classDict = getClass(packageDict,clazz)
    if not classDict:
        print("not class found!")
        return
    print("class found!!!!")
    methodDictList = classDict['methods']
    allConstStr = set()
    for methodIdentifier in methodDictList:
        methodDict = methodDictList[methodIdentifier]
        constStr = methodDict['constStr']
        allConstStr=allConstStr.union(set(constStr))
    InteractUtils.showList(allConstStr)
### 对结果字典进行格式化打印
def GetMatchedResult(resDict):
    '''
    打印匹配的结果
    '''
    ## 有这种情况 那就是调用runThread函数，一个是用java方法调用的，另一个是用自己实现的方法调用
    ## 这种情况下callee匹配不会准确的 除非将callee中的自定义方法都修改成父类java/安卓方法
    minCalleeLen = 3
    minSimilarity = 0.2
    idx = 0
    for clazz in resDict:
        methodDict = resDict[clazz]
        if clazz.startswith('androidx.') or clazz.startswith('org.') or clazz.startswith('com.ad'):
            continue
        for methodIdentifier in methodDict:
            idx+=1
            matchRes = methodDict[methodIdentifier]
            topN = matchRes['topN']
            callee = matchRes['callee']
            calleeLen = len(callee)
            if topN:
                if calleeLen<minCalleeLen or topN[0][1]['r']>minSimilarity:
                    continue
                
                print("line0:{}.{}".format(clazz,methodIdentifier))
                print("line1:{}.{}".format(clazz,topN[0][0]))
                print("similarity:{}".format(topN[0][1]['r']))
                print()
    print('methodNumber:{}'.format(idx))

### 2 查询字典，并且做计算 生成新的字段 例如特征生成
### 获取方法的特征向量，基础中基础，这是统一封装的接口
def getMethodFeature(className, methodDict, DeObfuscatedClazzSet=set(),useReplace=True):
    '''
    输入：
        className: 这个方法的类名
        methodDict:这个方法的包
    输出：
        这个方法的 签名特征字符串 callee特征字符串 和 常量字符串
    '''
    # 这里是查询是否有methodFeature字段，用于已经缓存过特征向量的字典
    res = getMethodFeature2(methodDict)
    if res:
        return res
    modifier = methodDict['modifier']
    methodName = methodDict['methodName']
    params = methodDict['methodParams']
    callers = methodDict['caller']
    # 对方法的参数归一化处理
    unifiedParams = []
    idx = 0
    for item in params:
        idx+=1
        if IsSysClazzOrDeObfuscated(item, DeObfuscatedClazzSet):
            unifiedParams.append(item)
        else:
            if useReplace:
                unifiedParams.append('x{}'.format(idx))
            else:
                unifiedParams.append(item)
    paramsStr = ''
    if unifiedParams:
        paramsStr = ', '.join(unifiedParams)
    retType = methodDict['retType']
    retStr = ''
    if retType:
        if IsSysClazzOrDeObfuscated(retType[0], DeObfuscatedClazzSet):
            retStr = retType[0]
        else:
            if useReplace:
                retStr = 'RET'
            else:
                retStr = retType[0]
    invokeList = methodDict['invoke']
    constStrList = methodDict['constStr']

    AllCallee = []
    sysAndDeObCallee = []
    ObfuscatedCallee = []
    for invokeDict in invokeList:
        isSysOrDeOb,invokeStr = getInvokeFeature(invokeDict, DeObfuscatedClazzSet,useReplace)
        AllCallee.append(invokeStr)
        if isSysOrDeOb or not useReplace:
            sysAndDeObCallee.append(invokeStr)
        else:
            ObfuscatedCallee.append(invokeStr)
    clazzParts = className.split('.')
    if '$' in clazzParts[-1]:
        clazzParts[-1] = 'c$c'
    else:
        clazzParts[-1] = 'c'
    for idx in range(len(clazzParts)-1):
        clazzParts[idx] = 'c'
    className = '.'.join(clazzParts)
    methodHeader = '{} {} {}.{}({})'.format(modifier, retStr, className,methodName,paramsStr)
    return methodHeader, constStrList, AllCallee, sysAndDeObCallee, ObfuscatedCallee
### 如果有特征字段，那么直接返回
def getMethodFeature2(methodDict):
    if 'methodFeature' not in methodDict:
        return ''
    else: 
        return methodDict['methodFeature']
### 获取callee特征，基础中的基础
def getInvokeFeature(invokeDict, DeObfuscatedClazzSet,useReplace=True):
    '''
    获取callee序列的特征
    输入：
        invokeDict:方法的callee字典
        DeObfuscatedClazzSet：两个版本共同的类交集，预设是没有混淆的类
        useReplace：对自定义且混淆的累是否采用x替换策略
    输入：
        方法的callee序列，syscallee序列，非syscallee序列
    '''
    invokeType = invokeDict['invokeType']
    className = invokeDict['className'][0]
    methodName = invokeDict['methodName']
    params = invokeDict['methodParams']
    IsSysOrDeOb = False
    if IsSysClazzOrDeObfuscated(className, DeObfuscatedClazzSet):
        IsSysOrDeOb = True
    unifiedParams = []
    idx = 0
    for item in params:
        idx+=1
        if IsSysClazzOrDeObfuscated(item, DeObfuscatedClazzSet):
            unifiedParams.append(item)
        else:
            if useReplace:
                unifiedParams.append('x{}'.format(idx))
            else:
                unifiedParams.append(item)
    paramsStr = ''
    if unifiedParams:
        paramsStr = ', '.join(unifiedParams)
    
    retType = invokeDict['retType']
    retStr = ''
    if retType:
        if IsSysClazzOrDeObfuscated(retType[0], DeObfuscatedClazzSet):
            retStr = retType[0]
        else:
            if useReplace:
                retStr = 'RET'
            else:
                retStr = retType[0]
    invokeStr = '{} {} {}.{}({})'.format(invokeType,retStr, className,methodName,paramsStr)
    return IsSysOrDeOb,invokeStr
### 查询或者计算方法的特征向量，根据packageDict的是否包含特征字段来区分 废弃
def findMethod(packageDict,className, methodName, params,intersecSet,useReplace=True):
    '''
    废弃方法，通过类名，方法名和参数来获得方法的特征向量
    '''
    res = ''
    className = className.strip()
    methodName = methodName.strip()

    classDict = getClass(packageDict, className)
    if not classDict:
        return res

    methodIdentifier = methodName+params
    methodDict = getMethod(classDict,methodIdentifier)
    
    if methodDict:
        res = getMethodFeature(className, methodDict,intersecSet,useReplace) 
    return res
### 查询或者计算方法的特征向量，根据packageDict的是否包含特征字段来区分
def findMethod2(packageDict, className, methodSig, intersecSet, useReplace=True):
    '''
    通过类名和方法签名获取方法的特征向量
    输入：
        packageDict：方法所在的包
        className:方法名
        methodSig：方法签名 除去类
    '''
    res = ''
    classDict = getClass(packageDict, className)
    if not classDict:
        return res
    methodDict = getMethod(classDict,methodSig)
    
    if methodDict:
        res = getMethodFeature(className, methodDict,intersecSet,useReplace)
    return res

### 打印一个方法的特征向量,对字典的简单查询，可能涉及到特征向量的计算
def printMethodFeature(basePackageDict, fullName, intersecSet, useReplace=True):
    '''
    打印一个方法的特征向量
    输入：
        basePackageDict：app包
        fullName：方法的完整签名
    输出：
        这个方法的callee列表，可以拓展成完整签名
    '''
    clazz, _, _, methodIdentifier = splitFullMethodName(fullName)
    baseMethodFeature = findMethod2(basePackageDict, clazz,methodIdentifier, intersecSet, useReplace)
    InteractUtils.showList(baseMethodFeature[2])
    return baseMethodFeature

# 关于解耦，参数尽量传元素而非列表，如下面，sameClazz是sameClazzList 元素
def getClazzMethodFeature(classDict, clazz,intersecSet, useReplace):
    '''
    获取这个class中所有方法的方法特征向量
    输入：
        ClassDict：这个类字典
        clazz：这个类名，比较冗余
    输出：
        所有方法签名及其对应的方法特征向量
    '''
    methodFeatureDict = {}
    methodDictList = classDict['methods']
    for methodIdentifer in methodDictList:
        #取出这个类中的所有方法
        methodDict = methodDictList[methodIdentifer]
        methodFeature = getMethodFeature(clazz, methodDict,intersecSet,useReplace)
        methodFeatureDict[methodIdentifer] = methodFeature
    return methodFeatureDict

### 生成类字段特征
def genFieldFeature(fieldsDict):
    staticFields = fieldsDict['staticFields']
    instanceFields = fieldsDict['instanceFields']
    staticTypeList = []
    instanceTypeList = []
    for item in staticFields:
        staticTypeList.append(staticFields[item]['type'][0])
    for item in instanceFields:
        instanceTypeList.append(instanceFields[item]['type'][0])
    return staticTypeList, instanceTypeList
### 生成class特征
def genClazzFeature(packageDict,clazz):
    classDict = packageDict[clazz]
    _genClazzFeature(classDict)
def _genClazzFeature(classDict):
    #'classModifier':classModifier,'super':supName,'implements':impList, 'imports':importList,'fields':fieldsDict,'methods':methodLists
    modifier = classDict['classModifier']
    supName = classDict['super']
    imports = classDict['imports']

    #修正import问题
    importList = []
    for item in imports:
        item = item[0]
        if ':L' in item:
            item = item.split(':L')[-1].strip('[')
        elif '[L' in item:
            item = item.split('[L')[-1]
        if item not in importList:
            importList.append(item)
    
    fieldsDict = classDict['fields']
    staticTypeList, instanceTypeList = genFieldFeature(fieldsDict)
    methodList = classDict['methods']
    methodIdentifiers = methodList.keys()
    for methodkey in methodList:
        methodDict = methodList[methodkey]
        
    print(modifier)
    print(supName)
    print(importList)
    print(staticTypeList)
    print(instanceTypeList)
    print(methodIdentifiers)

### 包生成，添加childClass字段，生成每个类的继承关系
def GenInherit(packageDict,newDictPath):
    for clazz in packageDict:
        classDict = packageDict[clazz]
        superCls = classDict['super']
        implementList = classDict['implements']
        if superCls and not superCls.startswith('java.') and not superCls.startswith('android.')\
            and not superCls.startswith('androidx.') and not superCls.startswith('org.')\
                and not superCls.startswith('javax.') and not superCls.startswith('com.google.')\
                and not superCls.startswith('com.samsung.android.sep')\
                    and not superCls.startswith('com.facebook.'):
            superClsDict = packageDict[superCls] #父类字典
            if 'childClass' in superClsDict:
                superClsDict['childClass'].append(clazz)
            else:
                superClsDict.update({'childClass':[clazz]})
        if implementList:
            for impl in implementList:
                if not impl.startswith('java.') and not impl.startswith('android.')\
                    and not impl.startswith('androidx.') and not impl.startswith('org.')\
                        and not impl.startswith('javax.')and not impl.startswith('com.google.')\
                            and not impl.startswith('com.facebook.'):#'jp.naver.line.android.b.e$d'
                    superClsDict = packageDict[impl] #接口字典
                    if 'childClass' in superClsDict:
                        superClsDict['childClass'].append(clazz)
                    else:
                        superClsDict.update({'childClass':[clazz]})

### 特征包的抽取，形成键值对的形式 其输出供traverseClazzMethod3使用
def extractAllMethodFeature(packageDict,intersecSet,useReplace):
    '''
    生成特征字典：
    提取出所有方法特征，用 方法签名:特征向量 的字典来存放，字典需要存起来
    packageDict: 目标app包结构
    intersecSet：如果动态生成的话需要这个结构，否则不用
    useReplace:动态生成的情况下是否需要替换自定义参数为 x
    '''
    resDict = {}
    for clazz in packageDict:
        classDict = packageDict[clazz]
        methodDictList = classDict['methods']
        for methodIdentifer in methodDictList:
            methodDict = methodDictList[methodIdentifer]
            targetMethodFeature = getMethodFeature(clazz, methodDict,intersecSet,useReplace)
            key = '{}.{}'.format(clazz,methodIdentifer)
            resDict[key] = targetMethodFeature
    return resDict
### 特征包的预计算，并且记录到字典，其输出供extractAllMethodFeature使用
def genAllClazzMethodFeature(packageDict, intersecSet,useReplace):
    '''
    生成一个app包下面所有方法的特征，并且存在每个方法字典的 methodFeature字段
    packageDict: 目标app包
    intersecSet：特征需要引入两个app之间的交集类
    useReplace：是否在生成特征的时候用x来替换自定义参数类
    '''
    idx = 0
    for clazz in packageDict:
        classDict = packageDict[clazz]
        methodDictList = classDict['methods']
        for methodIdentifer in methodDictList:
            idx +=1
            print(idx)
            #取出这个类中的所有方法
            key = "{}.{}".format(clazz, methodIdentifer)
            methodDict = methodDictList[methodIdentifer]
            # 首先看这个
            targetMethodFeature = getMethodFeature(clazz, methodDict,intersecSet,useReplace)
            methodDict['methodFeature'] = targetMethodFeature


### 3 高层算法 即新的字段参与的计算
## 匹配核心方法 计算两个特征向量之间的距离
def calFeatureSimilarity(baseMethodFeature, targetMethodFeature, useDebug=False):
    '''
    计算两个特征之间的距离，分别是第一个特征和第二个特征，useDebug会打印计算的距离值
    '''
    baseMethodHeader = str(baseMethodFeature[0])
    baseConstList = str(concatList(baseMethodFeature[1]))
    baseCallee = str(concatList(baseMethodFeature[2]))
    baseSysOrDeCallee = str(concatList(baseMethodFeature[3]))
    baseObfuscCallee = concatList(baseMethodFeature[4])

    baseMethodHeaderLen = float(len(baseMethodHeader))
    baseCalleeLen = float(len(baseCallee))
    baseSysOrDeCalleeLen = float(len(baseSysOrDeCallee))
    baseObfuscCalleeLen = float(len(baseObfuscCallee))

    targetMethodHeader = str(targetMethodFeature[0])
    targetConstList = str(concatList(targetMethodFeature[1]))
    targetCallee = str(concatList(targetMethodFeature[2]))
    targetSysOrDeCallee = str(concatList(targetMethodFeature[3]))
    targetObfuscCallee = concatList(targetMethodFeature[4])

    ## 对方法名进行相似度计算
    # print(baseMethodHeader,targetMethodHeader)
    # input()
    dist1 = Levenshtein.distance(baseMethodHeader,targetMethodHeader)
    partitionR1 = dist1/baseMethodHeaderLen
    # if partitionR1>1:
    #     partitionR1 = 1
    # partitionR1 = 1 - partitionR1
    
    # 对callee计算相似度
    if baseSysOrDeCallee:
        dist2 = Levenshtein.distance(baseSysOrDeCallee,targetSysOrDeCallee)
        partitionR2 = dist2/baseSysOrDeCalleeLen
        # if partitionR2>1:
        #     partitionR2 = 1
        # partitionR2 = jaccard_similarity(baseMethodFeature[3],targetMethodFeature[3])
        # print('baseSysOrDeCallee:\n{}\ntargetSysOrDeCallee:\n{}'.format(baseSysOrDeCallee,targetSysOrDeCallee))            
    else:
        dist2 = Levenshtein.distance(baseCallee,targetCallee)
        if not baseCallee and not targetCallee:
            partitionR2 = 0
        elif not baseCallee:
            partitionR2 = 1
        else:
            tmp = dist2/baseCalleeLen
            if tmp>1:
                partitionR2 = 1
            else:
                partitionR2 = tmp
    # partitionR2 = 1 - partitionR2

    useLevens = False
    partitionR3 = 0
    # 对常量字符串计算相似度
    if baseConstList:
        if useLevens:
            dist3 = Levenshtein.distance(baseConstList,targetConstList)
            partitionR3 = dist3/float(len(baseConstList))
            # print('baseConstList:{}\n\ntargetConstList:{}'.format(baseConstList,targetConstList))
        else:
            partitionR3 = jaccard_similarity(baseMethodFeature[1], targetMethodFeature[1])
            # print('baseConstList:{}\n\ntargetConstList:{}'.format(baseFeature[1],targetFeature[1]))     
            partitionR3 = 1-partitionR3
    if useDebug:
        print('basekey:{}\ntargetKey:{} \ndist:{} ratio:{}'.format(baseMethodHeader,targetMethodHeader,dist1,partitionR1))
        InteractUtils.showList(baseMethodFeature[3])
        print()
        InteractUtils.showList(targetMethodFeature[3])
        print('SysOrDeCallee ratio:{}'.format(partitionR2))
        print()
        print(baseMethodFeature[1])
        print()
        print(targetMethodFeature[1])
        print('constStr ratio:{}'.format(partitionR3))
        print('all ratio:{}'.format(partitionR1+partitionR2+partitionR3))
    return partitionR1, partitionR2, partitionR3, partitionR1+partitionR2

### 单方法匹配，低效，考虑废弃
def traverseClazzMethod(packageDict,baseMethodFeature, intersecSet,useReplace):
    '''
    单个方法的匹配，这个函数可以获取所有匹配距离，暂时还有用
    输入：
        packageDict: 需要全方法搜索的app包
        baseMethodFeature:目标方法的特征向量
    输出：
        这个方法的所有匹配结果排序列表，按距离从小到大排序
    '''
    sortedList = _traverseClazzMethod(packageDict, baseMethodFeature, intersecSet, useReplace)
    return sortedList
def _traverseClazzMethod(packageDict, baseMethodFeature, intersecSet,useReplace):
    a = 0.6
    low = 1-a
    high = 1+a
    resDict = {}
    sortedList = []
    baseLen = len(baseMethodFeature[2])+0.0
    #取出每一个类
    idx = 0
    for clazz in packageDict:
        classDict = packageDict[clazz]
        methodDictList = classDict['methods']
        for methodIdentifer in methodDictList:
            idx +=1
            #取出这个类中的所有方法
            key = "{}.{}".format(clazz, methodIdentifer)
            methodDict = methodDictList[methodIdentifer]
            # 首先看这个
            targetCalleeLen = getCalleeLen(methodDict)
            if targetCalleeLen>baseLen*low and targetCalleeLen<baseLen*high:
                targetMethodFeature = getMethodFeature(clazz, methodDict,intersecSet,useReplace)
                r1,r2,r3,rT = calFeatureSimilarity(baseMethodFeature, targetMethodFeature)
                resDict.update({key:rT})
                print(idx)
                print(methodIdentifer)
                print("similarity:{}".format(rT))
    sortedList = sorted(resDict.items(), key=lambda x:x[1])
    return sortedList
### 多方法同时匹配，低效，考虑废弃
def traverseClazzMethod2(packageDict, baseMethodFeatureDict, intersecSet,useReplace):
    '''
    实时生成方法的特征向量，效率过于低下，考虑废弃
    输入：
        packageDict:需要进行全方法遍历的包，原始包，不包含方法特征向量字段
        baseMethodFeatureDict:包含需要进行匹配的方法及其特征向量字典
    输出：
        baseMethodFeatureDict中的方法的匹配结果，其返回结果写入baseMethodFeatureDict字典中
    '''
    a = 0.6
    low = 1-a
    high = 1+a
    N = 3
    #取出每一个类
    idx = 0
    for key in baseMethodFeatureDict:
        cachedDict = baseMethodFeatureDict[key]
        if 'topN' not in cachedDict:
            cachedDict['topN'] = [('',100),('',100),('',100),('',100)]
    
    for clazz in packageDict:
        if not isCostomerClazz(clazz):
            continue
        classDict = packageDict[clazz]
        methodDictList = classDict['methods']
        for methodIdentifer in methodDictList:
            idx +=1
            #取出这个类中的所有方法
            key = "{}.{}".format(clazz, methodIdentifer)
            methodDict = methodDictList[methodIdentifer]
            # 首先看这个
            targetCalleeLen = getCalleeLen(methodDict)
            for baseKey in baseMethodFeatureDict:
                cachedDict = baseMethodFeatureDict[baseKey]
                baseMethodFeature = cachedDict['Feature']
                
                baseLen = len(baseMethodFeature[2])+0.0
                if targetCalleeLen>baseLen*low and targetCalleeLen<baseLen*high:
                    targetMethodFeature = getMethodFeature(clazz, methodDict,intersecSet,useReplace)

                    r1,r2,r3,rT = calFeatureSimilarity(baseMethodFeature, targetMethodFeature)
                    # middleResDict[baseKey].update({key:rT})
                    calTopN(cachedDict['topN'],N,(key,rT))
                    print(idx)
                    print(methodIdentifer)
                    print("similarity:{}".format(rT))
    return baseMethodFeatureDict
### 多方法同时匹配，高效
def traverseClazzMethod3(packageDict, baseMethodFeatureDict, intersecSet,useReplace):
    '''
    对特征向量列表进行全局搜索匹配
    输入：
        packageDict：目标app包的特征向量键值对
        baseMethodFeatureDict：目标特征向量列表
    输出：
        目标特征向量的topN匹配结果
    '''
    a = 0.6
    low = 1-a
    high = 1+a
    N = 3
    #取出每一个类
    idx = 0
    for key in baseMethodFeatureDict:
        cachedDict = baseMethodFeatureDict[key]
        if 'topN' not in cachedDict:
            cachedDict['topN'] = [('',100),('',100),('',100),('',100)]
        if 'length' not in cachedDict:
            cachedDict['length'] = 0
    
    for fullName in packageDict:
        idx+=1
        clazz,_,_,_=splitFullMethodName(fullName)
        if not isCostomerClazz(clazz):
            continue
        targetMethodFeature = packageDict[fullName]
        targetCalleeLen = len(targetMethodFeature[2])
        
        
        for baseKey in baseMethodFeatureDict:
            cachedDict = baseMethodFeatureDict[baseKey]
            baseMethodFeature = cachedDict['Feature']
            
            baseLen = len(baseMethodFeature[2])+0.0
            if targetCalleeLen>baseLen*low and targetCalleeLen<baseLen*high:
                r1,r2,r3,rT = calFeatureSimilarity(baseMethodFeature, targetMethodFeature)
                
                calTopN(cachedDict['topN'],N,(fullName,rT))
                cachedDict['length'] += 1
                print(idx)
                print(fullName)
                print("similarity:{}".format(rT))
    return baseMethodFeatureDict

### 鸡肋方法，对交集类之间进行匹配
def MatchSameClazz(baseDict, targetDict, sameClazz,intersecSet,useReplace):
    '''
    对两个包中的相同类的方法进行匹配，匹配范围仅限相同类，这个方法很鸡肋
    输入：
        baseDict：第一个app包
        targetDict：待匹配的app包
        sameClazz：相同的类名，即交集类
    输出：
        所有相同类中方法的匹配结果，存于字典中
    '''
    a = 0.8
    topN = 3
    classDict = baseDict[sameClazz]
    baseFeatureDict = getClazzMethodFeature(classDict, sameClazz,intersecSet,useReplace)

    targetClassDict = targetDict[sameClazz]
    targetFeatureDict = getClazzMethodFeature(targetClassDict, sameClazz,intersecSet,useReplace)
    resDict = {}
    for basekey in baseFeatureDict:
        baseFeature = baseFeatureDict[basekey]
        baseMethodHeader = baseFeature[0]
        baseConstList = concatList(baseFeature[1])
        baseCallee = concatList(baseFeature[2])
        baseSysOrDeCallee = concatList(baseFeature[3])
        baseObfuscCallee = concatList(baseFeature[4])

        baseMethodHeaderLen = float(len(baseMethodHeader))
        baseCalleeLen = float(len(baseCallee))
        baseSysOrDeCalleeLen = float(len(baseSysOrDeCallee))

        resDict[basekey] = {}
        resDict[basekey]['methodHeader'] = baseMethodHeader
        resDict[basekey]['const'] = baseFeature[1]
        resDict[basekey]['callee'] = baseFeature[2]
        
        matchingRes = {}
        matchingTopN = []
        for tkey in targetFeatureDict:
            targetFeature = targetFeatureDict[tkey]
            targetMethodHeader = targetFeature[0]
            targetConstList = concatList(targetFeature[1])
            targetCallee = concatList(targetFeature[2])
            targetSysOrDeCallee = concatList(targetFeature[3])
            targetObfuscCallee = concatList(targetFeature[4])
            matchingRes[tkey] = {}
            matchingRes[tkey]['methodHeader'] = targetMethodHeader
            matchingRes[tkey]['const'] = targetFeature[1]
            matchingRes[tkey]['callee'] = targetFeature[2]
            ## 对方法名进行相似度计算
            dist = Levenshtein.distance(baseMethodHeader,targetMethodHeader)
            partitionR1 = dist/baseMethodHeaderLen
            print('basekey:{}\ntargetKey:{} \ndist:{} ratio:{}'.format(baseMethodHeader,targetMethodHeader,dist,partitionR1))
            matchingRes[tkey]['r1'] = partitionR1
            # 对callee计算相似度
            if baseSysOrDeCallee:
                dist = Levenshtein.distance(baseSysOrDeCallee,targetSysOrDeCallee)
                partitionR2 = dist/baseSysOrDeCalleeLen
                # print('baseSysOrDeCallee:\n{}\ntargetSysOrDeCallee:\n{}'.format(baseSysOrDeCallee,targetSysOrDeCallee))
                print('SysOrDeCallee dist:{} ratio:{}'.format(dist,partitionR2))
            else:
                dist = Levenshtein.distance(baseCallee,targetCallee)
                if not baseCallee and not targetCallee:
                    partitionR2 = 0
                elif not baseCallee:
                    partitionR2 = 2
                else:
                    partitionR2 = dist/baseCalleeLen
                print('SysOrDeCallee dist:{} ratio:{}'.format(dist,partitionR2))
            matchingRes[tkey]['r2'] = partitionR2
            useLevens = False
            partitionR3 = 0
            # 对常量字符串计算相似度
            if baseConstList:
                if useLevens:
                    dist = Levenshtein.distance(baseConstList,targetConstList)
                    partitionR3 = dist/float(len(baseConstList))
                    # print('baseConstList:{}\n\ntargetConstList:{}'.format(baseConstList,targetConstList))
                    print('baseConstList Levenshtein dist:{} ratio:{}'.format(dist,partitionR3))
                else:
                    partitionR3 = jaccard_similarity(baseFeature[1], targetFeature[1])
                    # print('baseConstList:{}\n\ntargetConstList:{}'.format(baseFeature[1],targetFeature[1]))
                    print('jaccard_similarity dist:{} ratio:{}'.format(dist,partitionR3))
                partitionR3 = 1-partitionR3
            matchingRes[tkey]['r3'] = partitionR3
            matchingRes[tkey]['r'] = partitionR1+partitionR2+partitionR3
        sortedList = sorted(matchingRes.items(), key=lambda x:x[1]['r'])
        idx = 0
        for item in sortedList:
            idx += 1
            matchingTopN.append(item)
            if idx >= topN:
                break
        resDict[basekey]['topN'] = matchingTopN
    return resDict

### 对单个函数的全局搜索匹配 低效
def compareAll(basePackageDict, fullName, tarPackageDict,intersecSet,useReplace=True):
    '''
    对单个函数的全局搜索匹配 低效
    输入：
        basePackageDict：目标函数所在的app包
        fullName：目标函数的完整签名
        tarPackageDict：需要进行全局搜索的函数
    输出：
        这个函数的匹配所有匹配结果，排序
    '''
    clazz, _, _, methodIdentifier = splitFullMethodName(fullName)
    baseMethodFeature = findMethod2(basePackageDict, clazz,methodIdentifier, intersecSet, useReplace)
    print(fullName)
    resList = traverseClazzMethod(tarPackageDict, baseMethodFeature, intersecSet,useReplace)
    return resList

### 对一对函数进行匹配计算，多用于调试
def compareTwo(basePackageDict, fullName, tarPackageDict,fullName2,intersecSet,useReplace=True):
    '''
    对一对函数进行匹配计算，多用于调试
    输入：
        basePackageDict:第一个函数所在的app包
        fullName：第一个函数完整签名
        tarPackageDict：第二个函数所在的app包
        fullName2：第二个函数完整签名
    输出：
        特征向量之间的匹配结果，debug开启会打印出来
    '''
    clazz, _, _, methodIdentifier = splitFullMethodName(fullName)
    baseMethodFeature = findMethod2(basePackageDict, clazz,methodIdentifier, intersecSet, useReplace)

    clazz2, _, _, methodIdentifier2 = splitFullMethodName(fullName2)
    targetMethodFeature = findMethod2(tarPackageDict, clazz2,methodIdentifier2, intersecSet, useReplace)
    calFeatureSimilarity(baseMethodFeature,targetMethodFeature,True)

### 对两个列表的函数进行匹配 鸡肋
def getAccessment(basePackageDict, accessmentList, tarPackageDict, accessmentList2):
    '''
    对两个列表的函数进行匹配 鸡肋 两个列表需要在两个app包中一一对应
    输入：
        basePackageDict：第一个函数列表所在的app包
        accessmentList：第一个函数列表
    输出：
        函数列表的相互比较结果，是compareTwo的拓展
    '''
    tmpList = []
    idx = 0
    for item in accessmentList:
        clazz, methodName, params, methodIdentifier = splitFullMethodName(item)
        baseMethodFeature = findMethod2(basePackageDict, clazz,methodIdentifier, intersecSet, useReplace=True)

        item2 = accessmentList2[idx]
        clazz, methodName, params, methodIdentifier = splitFullMethodName(item2)
        targetMethodFeature = findMethod2(tarPackageDict, clazz,methodIdentifier, intersecSet, useReplace=True)
        partitionR1, partitionR2, partitionR3, rT=calFeatureSimilarity(baseMethodFeature,targetMethodFeature,True)

        tmpList.append('{}\t{}\t{}\t{}\t{}'.format(item,round(partitionR1,3),round(partitionR2,3),round(partitionR3,3),round(rT,3)))
        idx+=1
    return tmpList

### 实际的高效的方法列表全局搜索匹配算法
def doEvaluation(basePackageDict,filteredMethodList,tarPackageDict,intersecSet,useReplace=True):
    '''
    输入：
        basePackageDict：需要匹配的方法所在的app包
        filteredMethodList 需要进行特征匹配的方法签名序列
        tarPackageDict：特征向量键值对
    输出：
        每一个方法topN匹配结果，resDict
    对列表中的所有方法进行全app内方法匹配 全包一共有30万方法，100个方法进行匹配的时间大概是1h，2700个方法要27h
    注意tarPackageDict是cache过的特征dict
    '''
    resDict = {}
    for item in filteredMethodList:
        resDict[item] = {}
        ##求特征
        clazz, _, _, methodIdentifier = splitFullMethodName(item)
        baseMethodFeature = findMethod2(basePackageDict, clazz,methodIdentifier, intersecSet, useReplace=True)
        resDict[item]['Feature'] = baseMethodFeature
    traverseClazzMethod3(tarPackageDict,resDict,intersecSet,useReplace)
    return resDict
##现在的情况是大概有60%的函数能够精确地被找到，那么这些函数怎么办呢 首先把它们的混淆都收集起来
##混淆收集起来对混淆进行还原

### 0 字符串 容器 低级算法接口
### 1 查询字段 不做任何筛选等操作 包含统计信息 或者做一下筛选
### 2 查询字典，筛选并且计算新字段
### 3 匹配算法

### 首先为了加快寻找过程 我需要进行全局的字符串匹配

# getClazzConstStr(packageDict,clazz)

# %%
basePath = '/home/xcz/xline/tmp/line-9.22.2-addcaller.json'

# %%
basePackageDict = FileUtils.readDict(basePath)

# %%
queryMethod='j.a.a.a.l.j.c.d()'

# %%
getClazzConstStr(basePackageDict,"j.a.a.a.n2.h.m0")
# Out:
# class found!!!!
# 0: original
# 1: RICHMENU_CHECK
# 2: REPLACE
# 3: MENTION
# 4: FILE_NAME
# 5: STICON_OWNERSHIP
# 6: STKPKGID
# 7: STKVER
# 8: mid
# 9: DURATION
# 10: STKID
# 11: displayName
# 12: attribute
# 13: animated
# 14: file
# 15: width
# 16: height
# 17: fileSize
# 18: STKHASH
# 19: AUDLEN
# 20: STK_IMG_TXT
# 21: multiple_image_local_group_id
# 22: text
# 23: category
# 24: vCard
# 25: MEDIA_CONTENT_INFO
# 26: projectionType
# 27: message is null.(messageId=
# 28: STKOPT
# 29: equirectangular
# 30: extension
# 31: IS_SEND_ORIGINAL_IMAGE
# 32: true
# 33: FILE_SIZE

# %%
printClazzMethodIdenti(basePackageDict,'j.a.a.a.n2.h.m0')
# Out:
# 0: a(android.net.Uri,java.lang.String)
# 1: a(android.net.Uri,boolean,boolean)
# 2: a(android.net.Uri,j.a.b.b.h.i.b)
# 3: a(java.lang.String)
# 4: a(j.a.a.a.n2.h.l0$l)
# 5: <init>(j.a.a.a.k.d,j.a.a.a.n2.h.l0,j.a.a.a.n2.h.i0$a,j.a.a.a.n2.h.p0.j1,h2.j0.b.a)
# 6: run()
# 7: a(java.lang.String,android.net.Uri,j.a.a.a.b2.d.a,boolean,java.lang.String,java.lang.Long)
# 8: a(android.net.Uri)
# 9: a(java.lang.String,j.a.a.a.n2.h.m0$c)
# 10: <clinit>()
# 11: a(j.a.a.a.n2.h.l0$e)
# 12: a(j.a.a.a.n2.h.l0$k)
# 13: a(j.a.a.a.b2.d.a)
# dict_keys(['a(android.net.Uri,java.lang.String)', 'a(android.net.Uri,boolean,boolean)', 'a(android.net.Uri,j.a.b.b.h.i.b)', 'a(java.lang.String)', 'a(j.a.a.a.n2.h.l0$l)', '<init>(j.a.a.a.k.d,j.a.a.a.n2.h.l0,j.a.a.a.n2.h.i0$a,j.a.a.a.n2.h.p0.j1,h2.j0.b.a)', 'run()', 'a(java.lang.String,android.net.Uri,j.a.a.a.b2.d.a,boolean,java.lang.String,java.lang.Long)', 'a(android.net.Uri)', 'a(java.lang.String,j.a.a.a.n2.h.m0$c)', '<clinit>()', 'a(j.a.a.a.n2.h.l0$e)', 'a(j.a.a.a.n2.h.l0$k)', 'a(j.a.a.a.b2.d.a)'])

# %%
getCaller(basePackageDict,'j.a.a.a.n2.h.m0.<init>(j.a.a.a.k.d,j.a.a.a.n2.h.l0,j.a.a.a.n2.h.i0$a,j.a.a.a.n2.h.p0.j1,h2.j0.b.a)')
# Out:
# {'j.a.a.a.n2.h.i0': {'a(j.a.a.a.n2.h.l0,j.a.a.a.n2.h.i0$a)': 'direct/range'}}

# %%
printClazzMethodIdenti(basePackageDict,'j.a.a.a.y0.c')
# Out:
# 0: a(java.util.List)
# 1: a(android.content.Context,java.lang.String,boolean,boolean,boolean)
# 2: a(android.content.Context,java.lang.String,boolean)
# 3: d()
# 4: b()
# 5: a(j.a.e.a.b.be)
# 6: a(j.a.a.a.j.a.a.c)
# 7: a(jp.naver.line.android.db.main.model.ContactDto)
# 8: a(android.database.sqlite.SQLiteDatabase,java.lang.String,java.lang.String,java.lang.String,java.lang.String,java.lang.String,java.lang.String,java.lang.String,k.a.f.n.g.i.g,int)
# 9: a(int)
# 10: b(jp.naver.line.android.db.main.model.ContactDto)
# 11: b(int)
# 12: a(android.database.Cursor)
# 13: c()
# 14: a()
# dict_keys(['a(java.util.List)', 'a(android.content.Context,java.lang.String,boolean,boolean,boolean)', 'a(android.content.Context,java.lang.String,boolean)', 'd()', 'b()', 'a(j.a.e.a.b.be)', 'a(j.a.a.a.j.a.a.c)', 'a(jp.naver.line.android.db.main.model.ContactDto)', 'a(android.database.sqlite.SQLiteDatabase,java.lang.String,java.lang.String,java.lang.String,java.lang.String,java.lang.String,java.lang.String,java.lang.String,k.a.f.n.g.i.g,int)', 'a(int)', 'b(jp.naver.line.android.db.main.model.ContactDto)', 'b(int)', 'a(android.database.Cursor)', 'c()', 'a()'])

# %%
getCaller(basePackageDict,'j.a.a.a.y0.c.a(android.content.Context,java.lang.String,boolean)')
# Out:
# {'j.a.a.a.d.r0.t': {'onClick(android.view.View)': 'static'}, 'j.a.a.a.d.a.q6.b': {'onVoipButtonClicked(j.a.a.a.d.a.l6.u)': 'static'}, 'k.a.a.d.a.a.r.c$a': {'onClick(android.view.View)': 'static'}, 'j.a.a.a.d.v.r.k': {'b(android.view.View)': 'static', 'c(android.view.View)': 'static'}, 'j.a.a.a.d.r0.s': {'onClick(android.view.View)': 'static'}, 'j.a.a.a.b.c2.a': {'a(org.json.JSONObject)': 'static'}, 'j.a.a.a.d.v.e$a$a': {'onClick(android.view.View)': 'static'}, 'j.a.a.a.d.v.s.h': {'a(android.app.Activity)': 'static'}, 'j.a.a.a.d.v.e$a$b': {'onClick(android.view.View)': 'static'}, 'j.a.a.a.d.v.n': {'onClick(android.view.View)': 'static'}, 'j.a.a.a.d.c0.d.s.h': {'b()': 'static'}}

# %%
printClazzMethodIdenti(basePackageDict, "j.a.a.a.n2.h.i0")
# Out:
# 0: <init>(android.content.Context,j.a.a.a.k.d)
# 1: a(long)
# 2: a(java.lang.String,java.lang.String,long[],j.a.a.a.n2.h.i0$a)
# 3: b(long)
# 4: a(long,h2.j0.b.l)
# 5: a(j.a.a.a.n2.h.l0,j.a.a.a.n2.h.i0$a)
# dict_keys(['<init>(android.content.Context,j.a.a.a.k.d)', 'a(long)', 'a(java.lang.String,java.lang.String,long[],j.a.a.a.n2.h.i0$a)', 'b(long)', 'a(long,h2.j0.b.l)', 'a(j.a.a.a.n2.h.l0,j.a.a.a.n2.h.i0$a)'])

# %%
printClazzMethodIdenti(basePackageDict, "j.a.a.a.k.d")
# Out:
# 0: a(j.a.a.a.k.t.j,boolean)
# 1: a(h2.j0.b.l)
# 2: <init>(android.content.Context,j.a.a.a.h.e$b,android.database.sqlite.SQLiteDatabase,j.a.a.a.n2.h.w,j.a.a.a.k.s.a.z,j.a.a.a.j.a.a.c,j.a.a.a.j.a.a.d,j.a.a.a.k.s.a.g0,j.a.a.a.v0.n,j.a.a.a.j.a.a.e,j.a.a.a.j.a.a.f,j.a.a.a.k.i,j.a.a.a.j.a.a.s,j.a.a.a.e1.k.b,h2.j0.b.a,int)
# 3: a(java.lang.String)
# 4: a(j.a.a.a.k.d)
# 5: a(j.a.a.a.k.d,j.a.a.a.k.t.b)
# 6: b(j.a.a.a.k.d)
# 7: b(java.lang.String)
# 8: b()
# 9: a(java.lang.String,java.util.Set)
# 10: <clinit>()
# 11: a(j.a.a.a.k.t.b)
# 12: c()
# 13: a()
# dict_keys(['a(j.a.a.a.k.t.j,boolean)', 'a(h2.j0.b.l)', '<init>(android.content.Context,j.a.a.a.h.e$b,android.database.sqlite.SQLiteDatabase,j.a.a.a.n2.h.w,j.a.a.a.k.s.a.z,j.a.a.a.j.a.a.c,j.a.a.a.j.a.a.d,j.a.a.a.k.s.a.g0,j.a.a.a.v0.n,j.a.a.a.j.a.a.e,j.a.a.a.j.a.a.f,j.a.a.a.k.i,j.a.a.a.j.a.a.s,j.a.a.a.e1.k.b,h2.j0.b.a,int)', 'a(java.lang.String)', 'a(j.a.a.a.k.d)', 'a(j.a.a.a.k.d,j.a.a.a.k.t.b)', 'b(j.a.a.a.k.d)', 'b(java.lang.String)', 'b()', 'a(java.lang.String,java.util.Set)', '<clinit>()', 'a(j.a.a.a.k.t.b)', 'c()', 'a()'])

# %%
getCaller(basePackageDict,'j.a.a.a.k.d.<init>(android.content.Context,j.a.a.a.h.e$b,android.database.sqlite.SQLiteDatabase,j.a.a.a.n2.h.w,j.a.a.a.k.s.a.z,j.a.a.a.j.a.a.c,j.a.a.a.j.a.a.d,j.a.a.a.k.s.a.g0,j.a.a.a.v0.n,j.a.a.a.j.a.a.e,j.a.a.a.j.a.a.f,j.a.a.a.k.i,j.a.a.a.j.a.a.s,j.a.a.a.e1.k.b,h2.j0.b.a,int)')
# Out:
# {'j.a.a.a.k.r': {'a(android.content.Context)': 'direct/range'}, 'j.a.a.a.k.d$a': {'a(android.content.Context)': 'direct/range'}}

# %%
printClazzMethodIdenti(basePackageDict, "j.a.a.a.n2.h.p0.t3")
# Out:
# 0: a(android.content.Context,java.lang.String,java.lang.Long,j.a.e.a.b.hb,j.a.a.a.b2.d.a,long,k.a.b0.d,boolean,j.a.b.b.h.f,j.a.b.b.h.i.b)
# 1: a(java.lang.Long,j.a.a.a.k.a)
# 2: a(java.lang.String,java.lang.Exception)
# 3: a(long,j.a.a.a.n2.h.p0.j1$b)
# 4: <init>(j.a.a.a.k.d,java.util.Map,java.util.concurrent.ExecutorService,y5.c.u0.h,y5.c.u0.h)
# dict_keys(['a(android.content.Context,java.lang.String,java.lang.Long,j.a.e.a.b.hb,j.a.a.a.b2.d.a,long,k.a.b0.d,boolean,j.a.b.b.h.f,j.a.b.b.h.i.b)', 'a(java.lang.Long,j.a.a.a.k.a)', 'a(java.lang.String,java.lang.Exception)', 'a(long,j.a.a.a.n2.h.p0.j1$b)', '<init>(j.a.a.a.k.d,java.util.Map,java.util.concurrent.ExecutorService,y5.c.u0.h,y5.c.u0.h)'])

# %%
getClazzConstStr(basePackageDict, "j.a.a.a.v0.c0")
# Out:
# class found!!!!
# 0:
# 1: token
# 2: accuracy
# 3: \n
# 4:  is null.
# 5: shopType==
# 6: extra_video_profile_max_length_sec
# 7: failed parse shop handler parameters.
# 8: appVersion
# 9: MA_JSF
# 10: phone
# 11: products
# 12: Can only be registered either one of LocalAction and GlobalAction.
# 13:  is not supported.
# 14: extra_video_profile_src_video_y
# 15: failed parse shop handler parameters. name=
# 16: sticons_
# 17: data
# 18: tracking
# 19: vp.small
# 20: _newUpdated
# 21: v1
# 22: category
# 23: isUserReload
# 24: MA_SBJ
# 25: dcmstore://launch?url=http%3A%2F%2Fapps.dmkt-sp.jp%2FSpApps%2FdetailApp%3Fdcmstore_view%3Dnone%26cId%3D10000016892
# 26: mp4
# 27: altitude
# 28: actionName is null
# 29: app_version_code
# 30: sticon
# 31: tid
# 32: advertisingId
# 33: isTablet
# 34: .zip
# 35: callbackId
# 36: extra_video_profile_source_filepath
# 37: uuid
# 38: jp.naver.line.android.bo.settings.ChatSettingBO
# 39: MA_AUJ
# 40: longitude
# 41: extra_video_profile_result_video_width
# 42: auto_play_gif
# 43: extra_video_profile_overlay_guide_type
# 44: .json
# 45: extra_video_profile_result_video_height
# 46: latitude
# 47: _doNotRetry
# 48: jp.naver.line.android.
# 49: extra_video_profile_src_video_x
# 50: message
# 51: vp.sjpg
# 52: _small
# 53: .sjpg
# 54: extra_show_story_share
# 55: error
# 56: _k.png
# 57: meta_
# 58: IntentFilter is null
# 59: SHA-256
# 60: region
# 61: video_profile
# 62: type
# 63: coords
# 64: sjpg
# 65: searchType
# 66: tab_on.png
# 67: \t
# 68: tids
# 69: android
# 70: extra_video_profile_for_cover
# 71: timestamp
# 72: intent is null
# 73: MA_RAK
# 74: vp.mp4
# 75: themeshop
# 76: lang
# 77: enabled
# 78: Action is empty.
# 79: tab_off.png

# %%
getClazzConstStr(basePackageDict, "com.linecorp.voip.core.common.notification.VoipNotificationCommand")
# Out:
# class found!!!!
# 0: notification

# %%
genClazzFeature(basePackageDict,"j.a.a.a.k.d")
# Out:
# public final
# java.lang.Object
# ['j.a.a.a.j.u.b.h', 'jp.naver.line.android.talkop.processor.ReceiveOperationBatchManager', 'j.a.a.a.n2.h.w', 'j.a.a.a.k.t.h', 'kotlin.Metadata', 'j.a.a.a.k.e', 'j.a.a.a.j.a.a.c', 'j.a.a.a.k.d$c', 'jp.naver.line.android.chathistory.model.ChatHistoryMessageData', 'j.a.a.a.j.a.a.e', 'jp.naver.line.android.thrift.client.TalkServiceClient', 'java.util.List', 'java.lang.String', 'android.database.sqlite.SQLiteDatabase', 'j.a.a.a.k.h', 'jp.naver.line.android.bo.ChatBO', 'h2.j0.b.a', 'jp.naver.line.android.model.ChatData$ServiceType', 'j.a.a.a.k.d$f', 'j.a.a.a.k.s.a.z', 'j.a.a.a.k.t.j$b', 'j.a.a.a.k.t.j$a', 'j.a.a.a.k.d$e', 'j.a.a.a.k.t.j', 'java.util.Set', 'com.linecorp.line.ad.handler.AdContext', 'jp.naver.line.android.chathistory.model.MessageDataKey', 'j.a.a.a.t2.p1.b', 'kotlin.jvm.functions.Function0', 'android.content.Context', 'jp.naver.line.android.chathistory.impl.db.MultipleImageMessageMappingDao', 'j.a.a.a.h.e$b', 'h2.a.f', 'java.lang.Iterable', 'jp.naver.line.android.chathistory.MessageDataUpdater', 'java.util.Collections', 'j.a.a.a.k.u.a', 'h2.f', 'h2.a.d', 'j.a.a.a.j.a.a.s', 'j.a.e.a.b.hb', 'j.a.a.a.j.d', 'j.a.a.a.k.d$b', 'j.a.a.a.n2.h.i0', 'j.a.a.a.v0.n$b', 'j.a.a.a.k.d$g', 'j.a.a.a.k.s.a.x', 'j.a.a.a.k.d$d', 'k.a.c0.a$a', 'j.a.a.a.k.d', 'java.lang.Runnable', 'h2.a.o', 'j.a.a.a.k.d$a', 'h2.j0.c.k', 'j.a.a.a.j.a.a.f', 'j.a.a.a.k.d$i', 'j.a.a.a.k.t.b', 'k.a.c0.a', 'java.lang.Long', 'java.lang.Class', 'j.a.a.a.k.s.a.m', 'java.util.ArrayList', 'jp.naver.line.android.chathistory.MessageDataManager', 'h2.j0.c.a0', 'kotlin.Function0', 'j.a.a.a.b2.e.h', 'java.util.Collection', 'dalvik.annotation.Signature', 'j.a.a.a.a2.m.f', 'kotlin.Lazy', 'java.lang.Object', 'jp.naver.line.android.datasync.localdb.ChatSynchronizer', 'j.a.a.a.e1.k.b', 'j.a.a.a.p2.r0.f', 'j.a.a.a.v0.n', 'h2.j0.c.u', 'j.a.a.a.k.i', 'jp.naver.line.android.talkop.processor.SendMessageProcessor', 'h2.a.m', 'j.a.a.a.k.t.h$c', 'jp.naver.line.android.db.main.dao.PinnedChatDao', 'jp.naver.line.android.db.main.dao.ContactDao', 'dalvik.annotation.MemberClasses', 'jp.naver.line.android.chathistory.MessageDataSearcher', 'h2.j0.c.t', 'java.lang.Enum', 'jp.naver.line.android.db.main.dao.ChatDao', 'j.a.a.a.j.a.a.d', 'kotlin.Function1', 'jp.naver.line.android.chathistory.officialaccount.OaMessageEventTracker', 'jp.naver.line.android.chathistory.impl.db.NewChatHistoryDao', 'java.util.Iterator', 'h2.j0.b.l', 'h2.j0.c.f', 'j.a.a.a.k0.d.d', 'j.a.a.a.k.d$h', 'h2.a0', 'h2.i', 'jp.naver.line.android.db.main.dao.ChatHistoryDao', 'j.a.a.a.k.s.a.h0$a', 'j.a.a.a.k.s.a.g0', 'j.a.a.a.n2.h.w$b', 'jp.naver.line.android.db.main.dao.ChatSettingDao', 'j.a.a.a.k.f', 'j.a.a.a.k.t.m$b']
# ['h2.a.m[]', 'j.a.a.a.k.d$a']
# ['j.a.a.a.n2.h.w', 'j.a.a.a.k.s.a.z', 'j.a.a.a.k.i', 'h2.f', 'j.a.a.a.j.a.a.e', 'j.a.a.a.n2.h.i0', 'j.a.a.a.h.e$b', 'j.a.a.a.e1.k.b', 'j.a.a.a.k.s.a.g0', 'android.content.Context', 'j.a.a.a.j.a.a.c', 'j.a.a.a.j.a.a.d', 'j.a.a.a.v0.n', 'android.database.sqlite.SQLiteDatabase']
# dict_keys(['a(j.a.a.a.k.t.j,boolean)', 'a(h2.j0.b.l)', '<init>(android.content.Context,j.a.a.a.h.e$b,android.database.sqlite.SQLiteDatabase,j.a.a.a.n2.h.w,j.a.a.a.k.s.a.z,j.a.a.a.j.a.a.c,j.a.a.a.j.a.a.d,j.a.a.a.k.s.a.g0,j.a.a.a.v0.n,j.a.a.a.j.a.a.e,j.a.a.a.j.a.a.f,j.a.a.a.k.i,j.a.a.a.j.a.a.s,j.a.a.a.e1.k.b,h2.j0.b.a,int)', 'a(java.lang.String)', 'a(j.a.a.a.k.d)', 'a(j.a.a.a.k.d,j.a.a.a.k.t.b)', 'b(j.a.a.a.k.d)', 'b(java.lang.String)', 'b()', 'a(java.lang.String,java.util.Set)', '<clinit>()', 'a(j.a.a.a.k.t.b)', 'c()', 'a()'])

# %%
genClazzFeature(basePackageDict, "j.a.a.a.b2.e.h")
# Out:
# public
# java.lang.Object
# ['h2.b0', 'j.a.a.a.b2.e.v', 'j.a.a.a.g2.p.g', 'j.a.f.c.d.a', 'h2.d0.e0', 'h2.d0.i', 'j.a.a.a.t2.m1.d', 'v5.r.m', 'h2.n', 'j.a.b.b.h.g', 'java.lang.Throwable', 'java.io.FileNotFoundException', 'java.lang.Error', 'j.a.a.a.l.w.l$a', 'j.a.a.a.j.a.a.e', 'j.a.e.a.b.wb', 'j.a.a.a.h.a.o.d', 'android.os.Build', 'android.view.inputmethod.InputMethodManager', 'j.a.a.a.b2.e.n$a', 'java.io.BufferedInputStream', 'j.a.a.a.l.x.f.c', 'k.a.l.a.f', 'java.text.DecimalFormat', 'java.net.HttpURLConnection', 'jp.naver.line.android.db.main.model.ChatDto', 'java.lang.ArrayIndexOutOfBoundsException', 'java.io.Closeable', 'java.lang.OutOfMemoryError', 'java.util.Set', 'j.a.a.a.t2.t1.d', 'j.a.a.a.h.j0', 'java.util.zip.GZIPInputStream', 'j.a.a.a.j.a.a.a.b', 'h2.l$b', 'j.a.a.a.h2.i.a', 'j.a.e.a.b.he', 'k.k.c.a.d.s', 'android.util.Base64', 'v5.r.v', 'j.a.a.a.b2.e.h$c', 'j.a.a.a.j.u.c.a$b', 'java.io.File', 'j.a.a.a.l.r.d.j', 'j.a.a.a.h.g', 'j.a.a.a.j.a.a.m', 'java.lang.Exception', 'j.a.a.a.h.e', 'j.a.a.a.x2.d', 'android.util.AttributeSet', 'android.widget.Toast', 'j.a.a.a.k.s.a.x', 'java.util.Locale', 'j.a.a.a.b2.e.h$b', 'java.lang.CharSequence', 'android.view.View', 'j.a.a.a.h.o0', 'android.view.LayoutInflater', 'android.content.DialogInterface$OnClickListener', 'java.io.InputStream', 'j.a.a.a.l.f', 'j.a.a.a.t1.a', 'j.a.e.a.b.ce', 'k.a.p', 'android.graphics.BitmapFactory', 'java.util.Collection', 'j.a.a.a.l.j.a$d', 'j.a.a.a.a2.m.f$a', 'android.content.res.Configuration', 'j.a.a.a.t2.b', 'j.a.a.a.k.t.h$r', 'j.a.a.a.b2.d.b', 'j.a.a.a.k.i', 'j.a.a.a.t2.o$b', 'h2.d0.x', 'h2.d0.w', 'h2.n0.f', 'java.util.EnumSet', 'j.a.a.a.t2.j1.b', 'dalvik.annotation.MemberClasses', 'h2.k', 'j.a.a.a.t2.j1.a', 'j.a.a.a.k.t.g$a', 'androidx.recyclerview.widget.RecyclerView', 'j.a.a.a.j.a.f.z', 'java.net.URL', 'java.util.HashSet', 'java.lang.Float', 'org.apache.http.HeaderElement', 'j.a.a.a.l2.p.c', 'org.json.JSONArray', 'h2.a0', 'y5.c.v', 'android.net.Uri$Builder', 'android.text.Spanned', 'k.a.m0.a.a', 'j.a.a.a.j.c', 'java.security.NoSuchAlgorithmException', 'android.graphics.Bitmap', 'java.lang.ArithmeticException', 'h2.r', 'java.util.Date', 'j.a.a.a.n2.h.n', 'j.a.a.a.l.r.d.l', 'j.a.a.a.j.a.e.a', 'j.a.a.a.b2.d.c', 'h2.y', 'j.a.e.a.b.hb', 'j.a.a.a.l.x.f.d', 'java.lang.String', 'android.content.pm.PackageManager', 'j.a.a.a.j.a.a.c', 'j.a.a.a.l2.p.a', 'java.io.FileOutputStream', 'c6.a.a.b.f', 'h2.d0.d0', 'java.util.Arrays', 'j.a.f.d.c.a', 'k.k.b.c.a.w.b.k', 'jp.naver.line.android.thrift.client.TalkServiceClient', 'java.util.List', 'java.util.Comparator', 'android.view.View$OnApplyWindowInsetsListener', 'k.a.l.a.b', 'y5.c.r0.a', 'j.a.a.a.b2.e.o', 'android.database.sqlite.SQLiteDatabase', 'j.a.a.a.j.q$d', 'j.a.a.a.j.q$a', 'h2.j0.b.a', 'android.net.ConnectivityManager', 'h2.o0.m', 'j.a.a.a.t2.z$a', 'j.a.a.a.k.t.j$b', 'android.os.Parcelable', 'j.a.a.a.b2.e.k', 'j.a.a.a.j.q$d$d', 'j.a.f.c.d.g', 'java.lang.Iterable', 'h2.j0.c.d0', 'android.net.NetworkInfo', 'java.text.DateFormat', 'java.util.Collections', 'j.a.a.a.h2.i.a$b', 'j.a.a.a.o0.n', 'android.os.Looper', 'j.a.a.a.l.b.c', 'j.a.a.a.j.a.e.i', 'j.a.f.c.c.b', 'j.a.a.a.n2.h.p0.g3', 'j.a.a.a.a0', 'k.k.b.c.a.w.b.h', 'j.a.a.a.j.a.a.q', 'android.content.ActivityNotFoundException', '', 'h2.d0.m', 'j.a.f.c.d.b', 'javax.crypto.spec.SecretKeySpec', 'j.a.a.a.t2.n1.a', 'k.a.l.a.b$a', 'j.a.a.a.h.e$a', 'j.a.a.a.y1.d', 'j.a.a.a.t2.q1.a', 'android.text.SpannableStringBuilder', 'j.a.a.a.n2.h.q', 'j.a.a.a.v0.c0', 'org.json.JSONException', 'java.util.TimeZone', 'java.lang.AssertionError', 'android.util.SparseArray', 'j.a.a.a.j.a.e.b', 'j.a.a.a.h.a.o.a', 'j.a.a.a.e2.f$a', 'j.a.a.a.b2.e.u', 'j.a.a.a.g2.r.o', 'android.content.Intent', 'j.a.a.a.b2.e.h', 'j.a.a.a.o0.c', 'java.lang.Appendable', 'j.a.f.a', 'dalvik.annotation.Signature', 'j.a.a.a.g2.l', 'j.a.a.a.b2.e.s', 'h2.d0.t', 'j.a.a.a.v0.n', 'java.lang.Integer', 'j.a.a.a.b2.e.n', 'j.a.a.a.t2.m', 'j.a.a.a.d.a.j4', 'j.a.a.a.j.a.e.b$f', 'java.lang.StringBuilder', 'java.util.NoSuchElementException', 'android.gr ...
# ['long', 'long', 'j.a.f.c.d.b', 'j.a.f.c.d.g', 'int', 'j.a.a.a.b2.e.n$a', 'j.a.f.c.d.a']
# []
# dict_keys(['b(java.lang.Object)', 'a(android.content.Context,android.view.View)', 'a(int,int,int,int)', 'k(java.lang.Object[])', 'd(android.content.Context,java.lang.String)', 'a(java.lang.String,boolean)', 'a(android.content.Context,java.lang.String)', 'e(android.content.Context,java.lang.String)', 'a(android.app.Activity,java.lang.Throwable)', 'a(android.webkit.WebView,java.lang.String)', 'a(j.a.e.a.b.be)', 'a(org.json.JSONObject,java.lang.String)', 'c(java.lang.Object[])', 'c()', 'e(j.a.a.a.l2.o.a)', 'b(java.lang.Object[],java.lang.Object)', 'h()', 't()', 'b(android.content.Context,java.lang.String)', 'k()', 'j(java.lang.Object[])', 'a(java.lang.String,long,android.net.Uri,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,boolean,java.util.Map,j.a.a.a.b2.d.d,j.a.a.a.b2.e.n$a,java.lang.String,java.lang.Class)', 'g(java.lang.Object[])', 'a(java.lang.String,j.a.a.a.b2.e.s,java.util.Map)', 'a(java.util.Map,h2.j0.b.l)', 'a(java.lang.Object[],int)', 'c(android.content.Context)', 'f(j.a.a.a.l2.o.a)', 'a(java.lang.String,j.a.a.a.b2.d.b,java.util.Map)', 'a(short[],short)', 'a(java.lang.String,java.lang.String,j.a.a.a.b2.d.a,java.util.Map)', 'a(android.graphics.Bitmap,java.io.File)', 'a(android.widget.TextView,java.lang.CharSequence)', 'e(org.json.JSONObject,java.lang.String)', 'a(android.text.Spanned)', 'b(android.webkit.WebView,java.lang.String)', 'a(android.content.Context,java.lang.Throwable,android.os.Handler,boolean)', 'a(boolean,java.lang.String,long)', 'a(j.a.a.a.l2.o.e)', 'a(android.app.Activity,int,h2.j0.b.l,int)', 'd(long)', 'c(long,long)', 'a(java.lang.Object[],java.lang.CharSequence,java.lang.CharSequence,java.lang.CharSequence,int,java.lang.CharSequence,h2.j0.b.l,int)', 'b(java.lang.CharSequence[])', 'f(long)', 'b(org.apache.http.HttpResponse)', 'a(android.database.Cursor,int)', 'b(android.app.Activity,int)', 'a(android.util.AttributeSet,android.content.Context,int[],int,int,h2.j0.b.l,int)', 'b(long[])', 'a(java.lang.String,long,java.io.File,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.d.d)', 'a(android.content.Context,long)', 'm(java.lang.Object[])', 'a(android.widget.ImageView,androidx.lifecycle.LiveData,v5.r.m,h2.j0.b.l)', 'a(java.lang.Object[],java.lang.Object[])', 'b(java.util.Calendar)', 'a(java.io.InputStream,java.io.OutputStream,long,long,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,boolean)', 'c(java.util.Map)', 'a(android.content.Context,android.graphics.Bitmap,java.lang.String)', 'a(java.io.InputStream,int,j.a.a.a.l2.p.c,j.a.a.a.l2.p.b)', 'e()', 'a(java.lang.String,int)', 'a(java.lang.String,boolean,j.a.a.a.b2.e.n$a,java.util.Map)', 'b(java.lang.String)', 'a(long[])', 'f()', 'a(java.lang.Object[],java.util.Collection)', 'e(long)', 'd()', 'c(j.a.a.a.l2.o.a)', 'a(java.io.InputStream)', 'a(java.util.Collection,java.lang.Object[])', 'a(org.json.JSONObject,java.lang.String,int)', 'a(j.a.e.a.b.be,long,java.lang.String,java.lang.String,java.lang.String,j.a.a.a.h.e,j.a.a.a.j.a.e.b,j.a.a.a.k.t.b,boolean,boolean,boolean)', 'b(java.lang.String,java.util.Map)', 'c(java.lang.String,java.lang.String,j.a.a.a.b2.d.a,java.util.Map)', 'a(java.util.Collection,java.lang.Iterable)', 'b(android.app.Activity)', 'a(android.view.View,j.a.a.a.t2.j1.a)', 'a(int)', 'a(android.graphics.Bitmap,android.graphics.Bitmap,int)', 'c(java.util.Calendar)', 'a(java.lang.Object[],java.lang.Object)', 'a(android.database.sqlite.SQLiteDatabase,java.lang.String,java.lang.String[],java.lang.String,java.lang.String[],java.lang.String,java.lang.String,java.lang.String,java.lang.String,int)', 'b(android.content.Context,android.view.View)', 'b(android.content.Context,long)', 'h(java.lang.Object[])', 'c(android.content.Context,j.a.a.a.t2.o,long,long)', 'a(java.lang.Object[])', 'a(java.lang.String,long,long,long)', 'n()', 'b(h2.j0.b.a)', 'a(java.util.Map)', 'a(android.view.View)', 'a(int,int,int,int,long)', 'e(java.lang.String)', 'b(java.lang.String,java.io.InputStream,long,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.e.n$a,java ...

# %%
printMethodFeature(basePackageDict,"k.a.f.p.c.a.b.a(android.content.Context)",set(),False)
# Out:
# 0: virtual boolean java.util.concurrent.atomic.AtomicBoolean.getAndSet(boolean)
# 1: virtual boolean java.util.concurrent.atomic.AtomicBoolean.compareAndSet(boolean, boolean)
# 2: static void com.linecorp.voip.core.faceplay.db.FacePlayDatabase.a(android.content.Context)
# 3: direct void k.a.f.n.i.j.g.<init>(android.content.Context)
# 4: virtual java.lang.String android.content.Context.getPackageName()
# 5: static boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)
# 6: virtual java.lang.String java.lang.String.replace(java.lang.CharSequence, java.lang.CharSequence)
# 7: static java.lang.String k.a.f.n.i.a.b(java.lang.String)
# 8: virtual java.lang.String java.lang.String.toUpperCase()
# 9: static java.lang.StringBuilder k.d.a.a.a.b(java.lang.String, java.lang.String)
# 10: static j.a.a.a.l.j.a j.a.a.a.l.j.c.b()
# 11: virtual j.a.c.b.c.b j.a.a.a.k0.b.b.h()
# 12: virtual java.lang.String java.lang.Enum.name()
# 13: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 14: virtual java.lang.String java.lang.StringBuilder.toString()
# 15: static java.lang.String j.a.a.a.e2.d.b()
# 16: static java.util.Locale java.util.Locale.getDefault()
# 17: static java.lang.Integer java.lang.Integer.valueOf(int)
# 18: static java.util.Locale java.util.Locale.getDefault()
# 19: virtual java.lang.String java.util.Locale.toString()
# 20: static j.a.a.a.l.j.a j.a.a.a.l.j.c.b()
# 21: virtual java.lang.String j.a.a.a.k0.b.b.o()
# 22: static java.lang.String java.lang.String.format(java.util.Locale, java.lang.String, java.lang.Object[])
# 23: virtual void k.a.f.p.c.a.b.a(k.a.f.p.c.a.b$d)
# ('public boolean c.c.c.c.c.c.c.a(android.content.Context)',
#  ['UNKNOWN',
#   'android',
#   '',
#   ' ',
#   'androidapp.%s/%s (%s; U; Android %d; %s; occ-%s)'],
#  ['virtual boolean java.util.concurrent.atomic.AtomicBoolean.getAndSet(boolean)',
#   'virtual boolean java.util.concurrent.atomic.AtomicBoolean.compareAndSet(boolean, boolean)',
#   'static void com.linecorp.voip.core.faceplay.db.FacePlayDatabase.a(android.content.Context)',
#   'direct void k.a.f.n.i.j.g.<init>(android.content.Context)',
#   'virtual java.lang.String android.content.Context.getPackageName()',
#   'static boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)',
#   'virtual java.lang.String java.lang.String.replace(java.lang.CharSequence, java.lang.CharSequence)',
#   'static java.lang.String k.a.f.n.i.a.b(java.lang.String)',
#   'virtual java.lang.String java.lang.String.toUpperCase()',
#   'static java.lang.StringBuilder k.d.a.a.a.b(java.lang.String, java.lang.String)',
#   'static j.a.a.a.l.j.a j.a.a.a.l.j.c.b()',
#   'virtual j.a.c.b.c.b j.a.a.a.k0.b.b.h()',
#   'virtual java.lang.String java.lang.Enum.name()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.String java.lang.StringBuilder.toString()',
#   'static java.lang.String j.a.a.a.e2.d.b()',
#   'static java.util.Locale java.util.Locale.getDefault()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'static java.util.Locale java.util.Locale.getDefault()',
#   'virtual java.lang.String java.util.Locale.toString()',
#   'static j.a.a.a.l.j.a j.a.a.a.l.j.c.b()',
#   'virtual java.lang.String j.a.a.a.k0.b.b.o()',
#   'static java.lang.String java.lang.String.format(java.util.Locale, java.lang.String, java.lang.Object[])',
#   'virtual void k.a.f.p.c.a.b.a(k.a.f.p.c.a.b$d)'],
#  ['virtual boolean java.util.concurrent.atomic.AtomicBoolean.getAndSet(boolean)',
#   'virtual boolean java.util.concurrent.atomic.AtomicBoolean.compareAndSet(boolean, boolean)',
#   'static void com.linecorp.voip.core.faceplay.db.FacePlayDatabase.a(android.content.Context)',
#   'direct void k.a.f.n.i.j.g.<init>(android.content.Context)',
#   'virtual java.lang.String android.content.Context.getPackageName()',
#   'static boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)',
#   'virtual java.lang.String java.lang.String.replace(java.lang.CharSequence, java.lang.CharSequence)',
#   'static java.lang.String k.a.f.n.i.a.b(java.lang.String)',
#   'virtual java.lang.String java.lang.String.toUpperCase()',
#   'static java.lang.StringBuilder k.d.a.a.a.b(java.lang.String, java.lang.String)',
#   'static j.a.a.a.l.j.a j.a.a.a.l.j.c.b()',
#   'virtual j.a.c.b.c.b j.a.a.a.k0.b.b.h()',
#   'virtual java.lang.String java.lang.Enum.name()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.String java.lang.StringBuilder.toString()',
#   'static java.lang.String j.a.a.a.e2.d.b()',
#   'static java.util.Locale java.util.Locale.getDefault()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'static java.util.Locale java.util.Locale.getDefault()',
#   'virtual java.lang.String java.util.Locale.toString()',
#   'static j.a.a.a.l.j.a j.a.a.a.l.j.c.b()',
#   'virtual java.lang.String j.a.a.a.k0.b.b.o()',
#   'static java.lang.String java.lang.String.format(java.util.Locale, java.lang.String, java.lang.Object[])',
#   'virtual void k.a.f.p.c.a.b.a(k.a.f.p.c.a.b$d)'],
#  [])

# %%
getClazzConstStr(basePackageDict, "j.a.a.a.y0.c")
# Out:
# class found!!!!
# 0:
# 1: FreeCallLauncher
# 2: startFreeCallActivity

# %%
printMethodFeature(basePackageDict,"j.a.a.a.n2.h.m0.run()",set(),False)
# Out:
# 0: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 1: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 2: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 3: virtual java.lang.String j.a.a.a.k.t.g.b()
# 4: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 5: virtual java.lang.String j.a.a.a.h.g.a()
# 6: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 7: virtual java.lang.String j.a.a.a.h.o0.b()
# 8: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 9: static boolean j.a.a.a.v0.c0.o()
# 10: static java.lang.Boolean java.lang.Boolean.valueOf(boolean)
# 11: virtual void j.a.a.a.j.a.e.b.a(java.lang.Boolean)
# 12: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 13: virtual void j.a.a.a.v0.n.a(java.util.List)
# 14: direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)
# 15: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 16: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 17: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 18: static java.lang.String java.lang.String.valueOf(boolean)
# 19: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 20: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 21: virtual void j.a.a.a.v0.n.a(java.util.List)
# 22: direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)
# 23: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 24: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 25: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 26: static java.lang.Long java.lang.Long.valueOf(long)
# 27: static java.lang.String java.lang.String.valueOf(java.lang.Object)
# 28: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 29: static java.lang.Long java.lang.Long.valueOf(long)
# 30: static java.lang.String java.lang.String.valueOf(java.lang.Object)
# 31: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 32: static java.lang.Long java.lang.Long.valueOf(long)
# 33: static java.lang.String java.lang.String.valueOf(java.lang.Object)
# 34: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 35: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 36: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 37: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 38: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 39: virtual void j.a.a.a.v0.n.a(java.util.List)
# 40: direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)
# 41: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 42: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 43: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 44: virtual void j.a.a.a.v0.n.a(java.util.List)
# 45: direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)
# 46: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 47: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 48: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 49: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 50: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 51: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 52: virtual void j.a.a.a.v0.n.a(java.util.List)
# 53: direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)
# 54: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 55: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 56: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 57: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 58: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 59: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 60: virtual void j.a.a.a.v0.n.a(java.util.List)
# 61: direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)
# 62: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 63: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 64: interface java.lang.Object java.util.Map.get(java.lang.Object)
# 65: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 66: virtual void j.a.a.a.v0.n.a(java.util.List)
# 67: direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)
# 68: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 69: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 70: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 71: virtual long j.a.a.a.n2.h.m0$a.a(android.content.Context, android.net.Uri)
# 72: static java.lang.Long java.lang.Long.valueOf(long)
# 73: static java.lang.String java.lang.String.valueOf(java.lang.Object)
# 74: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 75: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 76: virtual void j.a.a.a.v0.n.a(java.util.List)
# 77: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 78: virtual long java.lang.Long.longValue()
# 79: static void j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, long, android.net.Uri)
# 80: direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)
# 81: direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)
# 82: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 83: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 84: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 85: virtual android.net.Uri j.a.a.a.n2.h.m0$a.a(j.a.a.a.b2.d.a)
# 86: virtual long j.a.a.a.n2.h.m0$a.a(android.content.Context, android.net.Uri)
# 87: static java.lang.Long java.lang.Long.valueOf(long)
# 88: static java.lang.String java.lang.String.valueOf(java.lang.Object)
# 89: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 90: virtual void j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b, j.a.a.a.b2.d.a)
# 91: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 92: virtual void j.a.a.a.v0.n.a(java.util.List)
# 93: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 94: virtual long java.lang.Long.longValue()
# 95: virtual android.net.Uri j.a.a.a.n2.h.m0$a.a(j.a.a.a.b2.d.a)
# 96: static void j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, long, android.net.Uri)
# 97: direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)
# 98: direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)
# 99: virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri)
# 100: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 101: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 102: virtual int android.graphics.Bitmap.getWidth()
# 103: static java.lang.Integer java.lang.Integer.valueOf(int)
# 104: virtual int android.graphics.Bitmap.getHeight()
# 105: static java.lang.Integer java.lang.Integer.valueOf(int)
# 106: virtual java.lang.String android.net.Uri.toString()
# 107: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 108: virtual void j.a.a.a.j.a.e.b.b(boolean)
# 109: virtual java.lang.String j.a.a.a.n2.h.m0.a(android.net.Uri, boolean, boolean)
# 110: virtual void j.a.a.a.j.a.e.b.e(java.lang.String)
# 111: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 112: virtual void j.a.a.a.v0.n.a(java.util.List)
# 113: virtual long java.lang.Long.longValue()
# 114: interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)
# 115: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 116: static java.io.File j.a.a.a.t2.p1.b.a(android.content.Context, android.net.Uri)
# 117: static/range j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.net.Uri, java.io.File, android.graphics.Bitmap, boolean)
# 118: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 119: virtual j.a.a.a.b2.d.a j.a.a.a.n2.h.m0.a(android.net.Uri, java.lang.String)
# 120: direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)
# 121: direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)
# 122: virtual j.a.a.a.n2.h.m j.a.a.a.n2.h.m0.a(j.a.a.a.n2.h.l0$k)
# 123: virtual j.a.a.a.n2.h.m j.a.a.a.n2.h.m0.a(j.a.a.a.n2.h.l0$e)
# 124: virtual j.a.a.a.n2.h.m j.a.a.a.n2.h.m0.a(j.a.a.a.n2.h.l0$l)
# 125: virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri, j.a.b.b.h.i.b)
# 126: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 127: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 128: virtual int android.graphics.Bitmap.getWidth()
# 129: static java.lang.Integer java.lang.Integer.valueOf(int)
# 130: virtual int android.graphics.Bitmap.getHeight()
# 131: static java.lang.Integer java.lang.Integer.valueOf(int)
# 132: static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)
# 133: virtual java.lang.String android.net.Uri.toString()
# 134: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 135: static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)
# 136: static long j.a.d.a.a.p.c.c(j.a.b.b.h.i.b)
# 137: direct void k.a.b0.d.<init>(long)
# 138: virtual k.a.b0.d j.a.a.a.n2.h.m0$a.a(android.content.Context, j.a.a.a.b2.d.a, j.a.a.a.h.u, android.net.Uri)
# 139: virtual void j.a.a.a.j.a.e.b.a(k.a.b0.d)
# 140: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 141: virtual void j.a.a.a.v0.n.a(java.util.List)
# 142: virtual long java.lang.Long.longValue()
# 143: interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)
# 144: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 145: static j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.graphics.Bitmap)
# 146: direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)
# 147: direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)
# 148: virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri, j.a.b.b.h.i.b)
# 149: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 150: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 151: virtual int android.graphics.Bitmap.getWidth()
# 152: static java.lang.Integer java.lang.Integer.valueOf(int)
# 153: virtual int android.graphics.Bitmap.getHeight()
# 154: static java.lang.Integer java.lang.Integer.valueOf(int)
# 155: static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)
# 156: virtual java.lang.String android.net.Uri.toString()
# 157: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 158: static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)
# 159: static long j.a.d.a.a.p.c.c(j.a.b.b.h.i.b)
# 160: direct void k.a.b0.d.<init>(long)
# 161: virtual k.a.b0.d j.a.a.a.n2.h.m0$a.a(android.content.Context, j.a.a.a.b2.d.a, j.a.a.a.h.u, android.net.Uri)
# 162: virtual void j.a.a.a.j.a.e.b.a(k.a.b0.d)
# 163: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 164: virtual void j.a.a.a.v0.n.a(java.util.List)
# 165: virtual long java.lang.Long.longValue()
# 166: interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)
# 167: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 168: static void j.a.a.a.t2.p1.b.b(android.content.Context, android.net.Uri)
# 169: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 170: static j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.graphics.Bitmap)
# 171: direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)
# 172: direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)
# 173: interface int java.lang.CharSequence.length()
# 174: direct void java.io.File.<init>(java.lang.String)
# 175: static android.net.Uri android.net.Uri.fromFile(java.io.File)
# 176: virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri, j.a.b.b.h.i.b)
# 177: virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(j.a.a.a.b2.d.a)
# 178: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 179: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 180: virtual int android.graphics.Bitmap.getWidth()
# 181: static java.lang.Integer java.lang.Integer.valueOf(int)
# 182: virtual int android.graphics.Bitmap.getHeight()
# 183: static java.lang.Integer java.lang.Integer.valueOf(int)
# 184: virtual java.lang.String android.net.Uri.toString()
# 185: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 186: virtual void j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b, j.a.a.a.b2.d.a)
# 187: virtual k.a.b0.d j.a.a.a.n2.h.m0$a.a(android.content.Context, j.a.a.a.b2.d.a, j.a.a.a.h.u, android.net.Uri)
# 188: virtual void j.a.a.a.j.a.e.b.a(k.a.b0.d)
# 189: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 190: virtual void j.a.a.a.v0.n.a(java.util.List)
# 191: virtual long java.lang.Long.longValue()
# 192: interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)
# 193: direct void java.io.File.<init>(java.lang.String)
# 194: virtual boolean java.io.File.exists()
# 195: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 196: static java.io.File j.a.a.a.t2.p1.b.a(java.lang.String, java.lang.Long, j.a.a.a.a0)
# 197: static void c6.a.a.b.c.a(java.io.File, java.io.File)
# 198: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 199: static j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.graphics.Bitmap)
# 200: direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)
# 201: direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)
# 202: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 203: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 204: virtual java.lang.String android.net.Uri.toString()
# 205: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 206: static j.a.a.a.l.x.f.a j.a.a.a.k.s.a.x.a(android.content.Context, android.net.Uri)
# 207: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 208: static java.lang.Long java.lang.Long.valueOf(long)
# 209: static java.lang.String java.lang.String.valueOf(java.lang.Object)
# 210: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 211: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 212: virtual void j.a.a.a.v0.n.a(java.util.List)
# 213: static j.a.a.a.l.x.f.a j.a.a.a.k.s.a.x.a(android.content.Context, android.net.Uri)
# 214: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 215: virtual long java.lang.Long.longValue()
# 216: static java.io.File j.a.a.a.j.u.b.h.a(java.lang.String, long, java.lang.String)
# 217: virtual android.content.ContentResolver android.content.Context.getContentResolver()
# 218: virtual java.io.InputStream android.content.ContentResolver.openInputStream(android.net.Uri)
# 219: static void c6.a.a.b.c.a(java.io.InputStream, java.io.File)
# 220: static void h2.d0.i0.a(java.io.Closeable, java.lang.Throwable)
# 221: static void h2.d0.i0.a(java.io.Closeable, java.lang.Throwable)
# 222: direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)
# 223: direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)
# 224: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 225: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 226: direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)
# 227: virtual void j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b, j.a.a.a.b2.d.a)
# 228: static java.util.List java.util.Collections.singletonList(java.lang.Object)
# 229: virtual void j.a.a.a.v0.n.a(java.util.List)
# 230: virtual java.lang.String android.net.Uri.getPath()
# 231: direct void java.io.File.<init>(java.lang.String)
# 232: virtual boolean java.io.File.exists()
# 233: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 234: virtual long java.lang.Long.longValue()
# 235: static java.io.File j.a.a.a.j.u.b.h.a(java.lang.String, long, java.lang.String)
# 236: static void c6.a.a.b.c.a(java.io.File, java.io.File)
# 237: direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)
# 238: direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)
# 239: static java.lang.Long java.lang.Long.valueOf(long)
# 240: virtual j.a.a.a.h.u j.a.a.a.v0.n.a(java.lang.Long)
# 241: virtual java.lang.String j.a.a.a.n2.h.l0.b()
# 242: virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)
# 243: direct void j.a.a.a.n2.h.n0.<init>(j.a.a.a.h.u)
# 244: direct void j.a.a.a.k.d$f.<init>(j.a.a.a.k.d, h2.j0.b.l)
# 245: static java.lang.Object j.a.a.a.k.s.a.x.b(android.database.sqlite.SQLiteDatabase, h2.j0.b.l)
# 246: virtual boolean j.a.a.a.n2.h.m0$a.a(j.a.e.a.b.hb)
# 247: virtual j.a.a.a.b2.d.a j.a.a.a.h.u.a()
# 248: direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)
# 249: direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)
# 250: direct void j.a.a.a.n2.h.m0$e.<init>(j.a.a.a.h.u)
# 251: direct void j.a.a.a.k.d$f.<init>(j.a.a.a.k.d, h2.j0.b.l)
# 252: static java.lang.Object j.a.a.a.k.s.a.x.b(android.database.sqlite.SQLiteDatabase, h2.j0.b.l)
# 253: virtual long java.lang.Long.longValue()
# 254: virtual long j.a.a.a.j.a.e.b.a(java.lang.String, java.lang.String, long)
# 255: virtual k.a.b0.d j.a.a.a.j.a.e.b.G()
# 256: virtual boolean j.a.a.a.j.a.e.b.a(java.lang.String)
# 257: virtual boolean j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b)
# 258: static java.lang.Boolean java.lang.Boolean.valueOf(boolean)
# 259: static boolean j.a.a.a.b2.e.h.a(java.lang.Boolean)
# 260: direct void j.a.b.b.h.f.<init>()
# 261: virtual void j.a.b.b.h.f.a(boolean)
# 262: static java.lang.Long java.lang.Long.valueOf(long)
# 263: virtual/range void j.a.a.a.n2.h.p0.t3.a(android.content.Context, java.lang.String, java.lang.Long, j.a.e.a.b.hb, j.a.a.a.b2.d.a, long, k.a.b0.d, boolean, j.a.b.b.h.f, j.a.b.b.h.i.b)
# 264: interface void j.a.a.a.n2.h.i0$a.a(j.a.a.a.h.u)
# 265: interface java.lang.Object java.util.List.get(int)
# 266: interface java.util.Iterator java.lang.Iterable.iterator()
# 267: interface boolean java.util.Iterator.hasNext()
# 268: interface java.lang.Object java.util.Iterator.next()
# 269: direct void j.a.a.a.n2.h.m0$d.<init>(j.a.a.a.n2.h.m$b$a, j.a.a.a.n2.h.m0, java.lang.Long)
# 270: direct void j.a.a.a.k.d$f.<init>(j.a.a.a.k.d, h2.j0.b.l)
# 271: static java.lang.Object j.a.a.a.k.s.a.x.b(android.database.sqlite.SQLiteDatabase, h2.j0.b.l)
# 272: interface void j.a.a.a.n2.h.i0$a.a(j.a.a.a.h.u)
# 273: static int j.a.a.a.b2.e.h.a(java.lang.Iterable, int)
# 274: direct void java.util.ArrayList.<init>(int)
# 275: interface java.util.Iterator java.lang.Iterable.iterator()
# 276: interface boolean java.util.Iterator.hasNext()
# 277: interface java.lang.Object java.util.Iterator.next()
# 278: virtual boolean j.a.a.a.j.a.e.b.a(java.lang.String)
# 279: static java.io.File j.a.a.a.t2.p1.b.a(java.lang.String, java.lang.Long, j.a.a.a.a0)
# 280: virtual long java.lang.Long.longValue()
# 281: virtual boolean j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b)
# 282: static java.lang.Boolean java.lang.Boolean.valueOf(boolean)
# 283: static boolean j.a.a.a.b2.e.h.a(java.lang.Boolean)
# 284: direct void j.a.b.b.h.f.<init>()
# 285: virtual void j.a.b.b.h.f.a(boolean)
# 286: direct/range void j.a.a.a.n2.h.p0.j1$e$a$a.<init>(long, j.a.a.a.b2.d.a, j.a.b.b.h.f, java.io.File, boolean)
# 287: interface boolean java.util.Collection.add(java.lang.Object)
# 288: direct void j.a.a.a.n2.h.p0.j1$e$a.<init>(java.lang.String, java.util.List)
# 289: virtual void j.a.a.a.n2.h.p0.j1.a(j.a.a.a.n2.h.p0.j1$e)
# 290: static boolean j.a.a.a.j.u.b.h.c()
# 291: static boolean com.linecorp.square.chat.SquareChatUtils.a(java.lang.String)
# 292: static void j.a.a.a.j.u.b.h.a(j.a.a.a.k.d, boolean, j.a.a.a.h.u, j.a.a.a.n2.h.e0)
# 293: direct void j.a.a.a.n2.h.p0.s3.<init>(j.a.a.a.k.d, j.a.a.a.h.u, boolean, j.a.a.a.n2.h.e0)
# 294: static boolean j.a.a.a.n2.h.j.B()
# 295: virtual void j.a.a.a.n2.h.j.b(j.a.a.a.n2.h.p0.s3)
# 296: static j.a.a.a.n2.h.g0 j.a.a.a.n2.h.g0.a()
# 297: interface void java.util.concurrent.Executor.execute(java.lang.Runnable)
# 298: interface void j.a.a.a.n2.h.i0$a.a(j.a.a.a.h.u)
# 299: interface void j.a.a.a.n2.h.i0$a.a(java.lang.Exception)
# 300: static java.lang.StringBuilder k.d.a.a.a.d(java.lang.String)
# 301: virtual java.lang.StringBuilder java.lang.StringBuilder.append(long)
# 302: virtual java.lang.StringBuilder java.lang.StringBuilder.append(char)
# 303: virtual java.lang.String java.lang.StringBuilder.toString()
# 304: virtual java.lang.String java.lang.Object.toString()
# 305: direct void java.lang.IllegalStateException.<init>(java.lang.String)
# 306: direct void h2.i.<init>()
# ('public void c.c.c.c.c.c.c.run()',
#  ['DURATION',
#   'MENTION',
#   'REPLACE',
#   'STICON_OWNERSHIP',
#   'RICHMENU_CHECK',
#   'STKPKGID',
#   'STKVER',
#   'STKID',
#   'STKOPT',
#   'STKHASH',
#   'STK_IMG_TXT',
#   'displayName',
#   'mid',
#   'vCard',
#   'text',
#   'FILE_NAME',
#   'FILE_SIZE',
#   'IS_SEND_ORIGINAL_IMAGE',
#   'AUDLEN',
#   'message is null.(messageId='],
#  ['virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual java.lang.String j.a.a.a.k.t.g.b()',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'virtual java.lang.String j.a.a.a.h.g.a()',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'virtual java.lang.String j.a.a.a.h.o0.b()',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static boolean j.a.a.a.v0.c0.o()',
#   'static java.lang.Boolean java.lang.Boolean.valueOf(boolean)',
#   'virtual void j.a.a.a.j.a.e.b.a(java.lang.Boolean)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'static java.lang.String java.lang.String.valueOf(boolean)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'interface java.lang.Object java.util.Map.get(java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual long j.a.a.a.n2.h.m0$a.a(android.content.Context, android.net.Uri)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual long java.lang.Long.longValue()',
#   'static void j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, long, android.net.Uri)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual android.net.Uri j.a.a.a.n2.h.m0$a.a(j.a.a.a.b2.d.a)',
#   'virtual long j.a.a.a.n2.h.m0$a.a(android.content.Context, android.net.Uri)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'virtual void j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b, j.a.a.a.b2.d.a)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual long java.lang.Long.longValue()',
#   'virtual android.net.Uri j.a.a.a.n2.h.m0$a.a(j.a.a.a.b2.d.a)',
#   'static void j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, long, android.net.Uri)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'virtual int android.graphics.Bitmap.getWidth()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual int android.graphics.Bitmap.getHeight()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual java.lang.String android.net.Uri.toString()',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual void j.a.a.a.j.a.e.b.b(boolean)',
#   'virtual java.lang.String j.a.a.a.n2.h.m0.a(android.net.Uri, boolean, boolean)',
#   'virtual void j.a.a.a.j.a.e.b.e(java.lang.String)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual long java.lang.Long.longValue()',
#   'interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static java.io.File j.a.a.a.t2.p1.b.a(android.content.Context, android.net.Uri)',
#   'static/range j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.net.Uri, java.io.File, android.graphics.Bitmap, boolean)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.b2.d.a j.a.a.a.n2.h.m0.a(android.net.Uri, java.lang.String)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual j.a.a.a.n2.h.m j.a.a.a.n2.h.m0.a(j.a.a.a.n2.h.l0$k)',
#   'virtual j.a.a.a.n2.h.m j.a.a.a.n2.h.m0.a(j.a.a.a.n2.h.l0$e)',
#   'virtual j.a.a.a.n2.h.m j.a.a.a.n2.h.m0.a(j.a.a.a.n2.h.l0$l)',
#   'virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri, j.a.b.b.h.i.b)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'virtual int android.graphics.Bitmap.getWidth()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual int android.graphics.Bitmap.getHeight()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)',
#   'virtual java.lang.String android.net.Uri.toString()',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)',
#   'static long j.a.d.a.a.p.c.c(j.a.b.b.h.i.b)',
#   'direct void k.a.b0.d.<init>(long)',
#   'virtual k.a.b0.d j.a.a.a.n2.h.m0$a.a(android.content.Context, j.a.a.a.b2.d.a, j.a.a.a.h.u, android.net.Uri)',
#   'virtual void j.a.a.a.j.a.e.b.a(k.a.b0.d)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual long java.lang.Long.longValue()',
#   'interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.graphics.Bitmap)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri, j.a.b.b.h.i.b)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'virtual int android.graphics.Bitmap.getWidth()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual int android.graphics.Bitmap.getHeight()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)',
#   'virtual java.lang.String android.net.Uri.toString()',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)',
#   'static long j.a.d.a.a.p.c.c(j.a.b.b.h.i.b)',
#   'direct void k.a.b0.d.<init>(long)',
#   'virtual k.a.b0.d j.a.a.a.n2.h.m0$a.a(android.content.Context, j.a.a.a.b2.d.a, j.a.a.a.h.u, android.net.Uri)',
#   'virtual void j.a.a.a.j.a.e.b.a(k.a.b0.d)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual long java.lang.Long.longValue()',
#   'interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static void j.a.a.a.t2.p1.b.b(android.content.Context, android.net.Uri)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.graphics.Bitmap)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'interface int java.lang.CharSequence.length()',
#   'direct void java.io.File.<init>(java.lang.String)',
#   'static android.net.Uri android.net.Uri.fromFile(java.io.File)',
#   'virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri, j.a.b.b.h.i.b)',
#   'virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(j.a.a.a.b2.d.a)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'virtual int android.graphics.Bitmap.getWidth()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual int android.graphics.Bitmap.getHeight()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual java.lang.String android.net.Uri.toString()',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual void j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b, j.a.a.a.b2.d.a)',
#   'virtual k.a.b0.d j.a.a.a.n2.h.m0$a.a(android.content.Context, j.a.a.a.b2.d.a, j.a.a.a.h.u, android.net.Uri)',
#   'virtual void j.a.a.a.j.a.e.b.a(k.a.b0.d)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual long java.lang.Long.longValue()',
#   'interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)',
#   'direct void java.io.File.<init>(java.lang.String)',
#   'virtual boolean java.io.File.exists()',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static java.io.File j.a.a.a.t2.p1.b.a(java.lang.String, java.lang.Long, j.a.a.a.a0)',
#   'static void c6.a.a.b.c.a(java.io.File, java.io.File)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.graphics.Bitmap)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'virtual java.lang.String android.net.Uri.toString()',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'static j.a.a.a.l.x.f.a j.a.a.a.k.s.a.x.a(android.content.Context, android.net.Uri)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'static j.a.a.a.l.x.f.a j.a.a.a.k.s.a.x.a(android.content.Context, android.net.Uri)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual long java.lang.Long.longValue()',
#   'static java.io.File j.a.a.a.j.u.b.h.a(java.lang.String, long, java.lang.String)',
#   'virtual android.content.ContentResolver android.content.Context.getContentResolver()',
#   'virtual java.io.InputStream android.content.ContentResolver.openInputStream(android.net.Uri)',
#   'static void c6.a.a.b.c.a(java.io.InputStream, java.io.File)',
#   'static void h2.d0.i0.a(java.io.Closeable, java.lang.Throwable)',
#   'static void h2.d0.i0.a(java.io.Closeable, java.lang.Throwable)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual void j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b, j.a.a.a.b2.d.a)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual java.lang.String android.net.Uri.getPath()',
#   'direct void java.io.File.<init>(java.lang.String)',
#   'virtual boolean java.io.File.exists()',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual long java.lang.Long.longValue()',
#   'static java.io.File j.a.a.a.j.u.b.h.a(java.lang.String, long, java.lang.String)',
#   'static void c6.a.a.b.c.a(java.io.File, java.io.File)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'virtual j.a.a.a.h.u j.a.a.a.v0.n.a(java.lang.Long)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.n2.h.n0.<init>(j.a.a.a.h.u)',
#   'direct void j.a.a.a.k.d$f.<init>(j.a.a.a.k.d, h2.j0.b.l)',
#   'static java.lang.Object j.a.a.a.k.s.a.x.b(android.database.sqlite.SQLiteDatabase, h2.j0.b.l)',
#   'virtual boolean j.a.a.a.n2.h.m0$a.a(j.a.e.a.b.hb)',
#   'virtual j.a.a.a.b2.d.a j.a.a.a.h.u.a()',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'direct void j.a.a.a.n2.h.m0$e.<init>(j.a.a.a.h.u)',
#   'direct void j.a.a.a.k.d$f.<init>(j.a.a.a.k.d, h2.j0.b.l)',
#   'static java.lang.Object j.a.a.a.k.s.a.x.b(android.database.sqlite.SQLiteDatabase, h2.j0.b.l)',
#   'virtual long java.lang.Long.longValue()',
#   'virtual long j.a.a.a.j.a.e.b.a(java.lang.String, java.lang.String, long)',
#   'virtual k.a.b0.d j.a.a.a.j.a.e.b.G()',
#   'virtual boolean j.a.a.a.j.a.e.b.a(java.lang.String)',
#   'virtual boolean j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b)',
#   'static java.lang.Boolean java.lang.Boolean.valueOf(boolean)',
#   'static boolean j.a.a.a.b2.e.h.a(java.lang.Boolean)',
#   'direct void j.a.b.b.h.f.<init>()',
#   'virtual void j.a.b.b.h.f.a(boolean)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'virtual/range void j.a.a.a.n2.h.p0.t3.a(android.content.Context, java.lang.String, java.lang.Long, j.a.e.a.b.hb, j.a.a.a.b2.d.a, long, k.a.b0.d, boolean, j.a.b.b.h.f, j.a.b.b.h.i.b)',
#   'interface void j.a.a.a.n2.h.i0$a.a(j.a.a.a.h.u)',
#   'interface java.lang.Object java.util.List.get(int)',
#   'interface java.util.Iterator java.lang.Iterable.iterator()',
#   'interface boolean java.util.Iterator.hasNext()',
#   'interface java.lang.Object java.util.Iterator.next()',
#   'direct void j.a.a.a.n2.h.m0$d.<init>(j.a.a.a.n2.h.m$b$a, j.a.a.a.n2.h.m0, java.lang.Long)',
#   'direct void j.a.a.a.k.d$f.<init>(j.a.a.a.k.d, h2.j0.b.l)',
#   'static java.lang.Object j.a.a.a.k.s.a.x.b(android.database.sqlite.SQLiteDatabase, h2.j0.b.l)',
#   'interface void j.a.a.a.n2.h.i0$a.a(j.a.a.a.h.u)',
#   'static int j.a.a.a.b2.e.h.a(java.lang.Iterable, int)',
#   'direct void java.util.ArrayList.<init>(int)',
#   'interface java.util.Iterator java.lang.Iterable.iterator()',
#   'interface boolean java.util.Iterator.hasNext()',
#   'interface java.lang.Object java.util.Iterator.next()',
#   'virtual boolean j.a.a.a.j.a.e.b.a(java.lang.String)',
#   'static java.io.File j.a.a.a.t2.p1.b.a(java.lang.String, java.lang.Long, j.a.a.a.a0)',
#   'virtual long java.lang.Long.longValue()',
#   'virtual boolean j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b)',
#   'static java.lang.Boolean java.lang.Boolean.valueOf(boolean)',
#   'static boolean j.a.a.a.b2.e.h.a(java.lang.Boolean)',
#   'direct void j.a.b.b.h.f.<init>()',
#   'virtual void j.a.b.b.h.f.a(boolean)',
#   'direct/range void j.a.a.a.n2.h.p0.j1$e$a$a.<init>(long, j.a.a.a.b2.d.a, j.a.b.b.h.f, java.io.File, boolean)',
#   'interface boolean java.util.Collection.add(java.lang.Object)',
#   'direct void j.a.a.a.n2.h.p0.j1$e$a.<init>(java.lang.String, java.util.List)',
#   'virtual void j.a.a.a.n2.h.p0.j1.a(j.a.a.a.n2.h.p0.j1$e)',
#   'static boolean j.a.a.a.j.u.b.h.c()',
#   'static boolean com.linecorp.square.chat.SquareChatUtils.a(java.lang.String)',
#   'static void j.a.a.a.j.u.b.h.a(j.a.a.a.k.d, boolean, j.a.a.a.h.u, j.a.a.a.n2.h.e0)',
#   'direct void j.a.a.a.n2.h.p0.s3.<init>(j.a.a.a.k.d, j.a.a.a.h.u, boolean, j.a.a.a.n2.h.e0)',
#   'static boolean j.a.a.a.n2.h.j.B()',
#   'virtual void j.a.a.a.n2.h.j.b(j.a.a.a.n2.h.p0.s3)',
#   'static j.a.a.a.n2.h.g0 j.a.a.a.n2.h.g0.a()',
#   'interface void java.util.concurrent.Executor.execute(java.lang.Runnable)',
#   'interface void j.a.a.a.n2.h.i0$a.a(j.a.a.a.h.u)',
#   'interface void j.a.a.a.n2.h.i0$a.a(java.lang.Exception)',
#   'static java.lang.StringBuilder k.d.a.a.a.d(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(long)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(char)',
#   'virtual java.lang.String java.lang.StringBuilder.toString()',
#   'virtual java.lang.String java.lang.Object.toString()',
#   'direct void java.lang.IllegalStateException.<init>(java.lang.String)',
#   'direct void h2.i.<init>()'],
#  ['virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual java.lang.String j.a.a.a.k.t.g.b()',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'virtual java.lang.String j.a.a.a.h.g.a()',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'virtual java.lang.String j.a.a.a.h.o0.b()',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static boolean j.a.a.a.v0.c0.o()',
#   'static java.lang.Boolean java.lang.Boolean.valueOf(boolean)',
#   'virtual void j.a.a.a.j.a.e.b.a(java.lang.Boolean)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'static java.lang.String java.lang.String.valueOf(boolean)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'interface java.lang.Object java.util.Map.get(java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual long j.a.a.a.n2.h.m0$a.a(android.content.Context, android.net.Uri)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual long java.lang.Long.longValue()',
#   'static void j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, long, android.net.Uri)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual android.net.Uri j.a.a.a.n2.h.m0$a.a(j.a.a.a.b2.d.a)',
#   'virtual long j.a.a.a.n2.h.m0$a.a(android.content.Context, android.net.Uri)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'virtual void j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b, j.a.a.a.b2.d.a)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual long java.lang.Long.longValue()',
#   'virtual android.net.Uri j.a.a.a.n2.h.m0$a.a(j.a.a.a.b2.d.a)',
#   'static void j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, long, android.net.Uri)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'virtual int android.graphics.Bitmap.getWidth()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual int android.graphics.Bitmap.getHeight()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual java.lang.String android.net.Uri.toString()',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual void j.a.a.a.j.a.e.b.b(boolean)',
#   'virtual java.lang.String j.a.a.a.n2.h.m0.a(android.net.Uri, boolean, boolean)',
#   'virtual void j.a.a.a.j.a.e.b.e(java.lang.String)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual long java.lang.Long.longValue()',
#   'interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static java.io.File j.a.a.a.t2.p1.b.a(android.content.Context, android.net.Uri)',
#   'static/range j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.net.Uri, java.io.File, android.graphics.Bitmap, boolean)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.b2.d.a j.a.a.a.n2.h.m0.a(android.net.Uri, java.lang.String)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual j.a.a.a.n2.h.m j.a.a.a.n2.h.m0.a(j.a.a.a.n2.h.l0$k)',
#   'virtual j.a.a.a.n2.h.m j.a.a.a.n2.h.m0.a(j.a.a.a.n2.h.l0$e)',
#   'virtual j.a.a.a.n2.h.m j.a.a.a.n2.h.m0.a(j.a.a.a.n2.h.l0$l)',
#   'virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri, j.a.b.b.h.i.b)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'virtual int android.graphics.Bitmap.getWidth()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual int android.graphics.Bitmap.getHeight()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)',
#   'virtual java.lang.String android.net.Uri.toString()',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)',
#   'static long j.a.d.a.a.p.c.c(j.a.b.b.h.i.b)',
#   'direct void k.a.b0.d.<init>(long)',
#   'virtual k.a.b0.d j.a.a.a.n2.h.m0$a.a(android.content.Context, j.a.a.a.b2.d.a, j.a.a.a.h.u, android.net.Uri)',
#   'virtual void j.a.a.a.j.a.e.b.a(k.a.b0.d)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual long java.lang.Long.longValue()',
#   'interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.graphics.Bitmap)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri, j.a.b.b.h.i.b)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'virtual int android.graphics.Bitmap.getWidth()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual int android.graphics.Bitmap.getHeight()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)',
#   'virtual java.lang.String android.net.Uri.toString()',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'static boolean j.a.d.a.a.p.c.b(j.a.b.b.h.i.b)',
#   'static long j.a.d.a.a.p.c.c(j.a.b.b.h.i.b)',
#   'direct void k.a.b0.d.<init>(long)',
#   'virtual k.a.b0.d j.a.a.a.n2.h.m0$a.a(android.content.Context, j.a.a.a.b2.d.a, j.a.a.a.h.u, android.net.Uri)',
#   'virtual void j.a.a.a.j.a.e.b.a(k.a.b0.d)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual long java.lang.Long.longValue()',
#   'interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static void j.a.a.a.t2.p1.b.b(android.content.Context, android.net.Uri)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.graphics.Bitmap)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'interface int java.lang.CharSequence.length()',
#   'direct void java.io.File.<init>(java.lang.String)',
#   'static android.net.Uri android.net.Uri.fromFile(java.io.File)',
#   'virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(android.net.Uri, j.a.b.b.h.i.b)',
#   'virtual android.graphics.Bitmap j.a.a.a.n2.h.m0.a(j.a.a.a.b2.d.a)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'virtual int android.graphics.Bitmap.getWidth()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual int android.graphics.Bitmap.getHeight()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'virtual java.lang.String android.net.Uri.toString()',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual void j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b, j.a.a.a.b2.d.a)',
#   'virtual k.a.b0.d j.a.a.a.n2.h.m0$a.a(android.content.Context, j.a.a.a.b2.d.a, j.a.a.a.h.u, android.net.Uri)',
#   'virtual void j.a.a.a.j.a.e.b.a(k.a.b0.d)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual long java.lang.Long.longValue()',
#   'interface void j.a.a.a.n2.h.i0$a.a(long, android.graphics.Bitmap, boolean)',
#   'direct void java.io.File.<init>(java.lang.String)',
#   'virtual boolean java.io.File.exists()',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static java.io.File j.a.a.a.t2.p1.b.a(java.lang.String, java.lang.Long, j.a.a.a.a0)',
#   'static void c6.a.a.b.c.a(java.io.File, java.io.File)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'static j.a.a.a.t2.p1.b$a j.a.a.a.t2.p1.b.a(android.content.Context, java.lang.String, java.lang.Long, android.graphics.Bitmap)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'virtual java.lang.String android.net.Uri.toString()',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'static j.a.a.a.l.x.f.a j.a.a.a.k.s.a.x.a(android.content.Context, android.net.Uri)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'static java.lang.String java.lang.String.valueOf(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'static j.a.a.a.l.x.f.a j.a.a.a.k.s.a.x.a(android.content.Context, android.net.Uri)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual long java.lang.Long.longValue()',
#   'static java.io.File j.a.a.a.j.u.b.h.a(java.lang.String, long, java.lang.String)',
#   'virtual android.content.ContentResolver android.content.Context.getContentResolver()',
#   'virtual java.io.InputStream android.content.ContentResolver.openInputStream(android.net.Uri)',
#   'static void c6.a.a.b.c.a(java.io.InputStream, java.io.File)',
#   'static void h2.d0.i0.a(java.io.Closeable, java.lang.Throwable)',
#   'static void h2.d0.i0.a(java.io.Closeable, java.lang.Throwable)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.j.a.e.b.<init>(java.util.Map, int)',
#   'virtual void j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b, j.a.a.a.b2.d.a)',
#   'static java.util.List java.util.Collections.singletonList(java.lang.Object)',
#   'virtual void j.a.a.a.v0.n.a(java.util.List)',
#   'virtual java.lang.String android.net.Uri.getPath()',
#   'direct void java.io.File.<init>(java.lang.String)',
#   'virtual boolean java.io.File.exists()',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual long java.lang.Long.longValue()',
#   'static java.io.File j.a.a.a.j.u.b.h.a(java.lang.String, long, java.lang.String)',
#   'static void c6.a.a.b.c.a(java.io.File, java.io.File)',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$a.<init>(java.lang.Exception)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'virtual j.a.a.a.h.u j.a.a.a.v0.n.a(java.lang.Long)',
#   'virtual java.lang.String j.a.a.a.n2.h.l0.b()',
#   'virtual j.a.a.a.h.u j.a.a.a.n2.h.m0.a(java.lang.String)',
#   'direct void j.a.a.a.n2.h.n0.<init>(j.a.a.a.h.u)',
#   'direct void j.a.a.a.k.d$f.<init>(j.a.a.a.k.d, h2.j0.b.l)',
#   'static java.lang.Object j.a.a.a.k.s.a.x.b(android.database.sqlite.SQLiteDatabase, h2.j0.b.l)',
#   'virtual boolean j.a.a.a.n2.h.m0$a.a(j.a.e.a.b.hb)',
#   'virtual j.a.a.a.b2.d.a j.a.a.a.h.u.a()',
#   'direct void j.a.a.a.n2.h.m$d.<init>(j.a.a.a.h.u, j.a.a.a.b2.d.a, j.a.b.b.h.i.b)',
#   'direct void j.a.a.a.n2.h.m$c.<init>(j.a.a.a.h.u)',
#   'direct void j.a.a.a.n2.h.m0$e.<init>(j.a.a.a.h.u)',
#   'direct void j.a.a.a.k.d$f.<init>(j.a.a.a.k.d, h2.j0.b.l)',
#   'static java.lang.Object j.a.a.a.k.s.a.x.b(android.database.sqlite.SQLiteDatabase, h2.j0.b.l)',
#   'virtual long java.lang.Long.longValue()',
#   'virtual long j.a.a.a.j.a.e.b.a(java.lang.String, java.lang.String, long)',
#   'virtual k.a.b0.d j.a.a.a.j.a.e.b.G()',
#   'virtual boolean j.a.a.a.j.a.e.b.a(java.lang.String)',
#   'virtual boolean j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b)',
#   'static java.lang.Boolean java.lang.Boolean.valueOf(boolean)',
#   'static boolean j.a.a.a.b2.e.h.a(java.lang.Boolean)',
#   'direct void j.a.b.b.h.f.<init>()',
#   'virtual void j.a.b.b.h.f.a(boolean)',
#   'static java.lang.Long java.lang.Long.valueOf(long)',
#   'virtual/range void j.a.a.a.n2.h.p0.t3.a(android.content.Context, java.lang.String, java.lang.Long, j.a.e.a.b.hb, j.a.a.a.b2.d.a, long, k.a.b0.d, boolean, j.a.b.b.h.f, j.a.b.b.h.i.b)',
#   'interface void j.a.a.a.n2.h.i0$a.a(j.a.a.a.h.u)',
#   'interface java.lang.Object java.util.List.get(int)',
#   'interface java.util.Iterator java.lang.Iterable.iterator()',
#   'interface boolean java.util.Iterator.hasNext()',
#   'interface java.lang.Object java.util.Iterator.next()',
#   'direct void j.a.a.a.n2.h.m0$d.<init>(j.a.a.a.n2.h.m$b$a, j.a.a.a.n2.h.m0, java.lang.Long)',
#   'direct void j.a.a.a.k.d$f.<init>(j.a.a.a.k.d, h2.j0.b.l)',
#   'static java.lang.Object j.a.a.a.k.s.a.x.b(android.database.sqlite.SQLiteDatabase, h2.j0.b.l)',
#   'interface void j.a.a.a.n2.h.i0$a.a(j.a.a.a.h.u)',
#   'static int j.a.a.a.b2.e.h.a(java.lang.Iterable, int)',
#   'direct void java.util.ArrayList.<init>(int)',
#   'interface java.util.Iterator java.lang.Iterable.iterator()',
#   'interface boolean java.util.Iterator.hasNext()',
#   'interface java.lang.Object java.util.Iterator.next()',
#   'virtual boolean j.a.a.a.j.a.e.b.a(java.lang.String)',
#   'static java.io.File j.a.a.a.t2.p1.b.a(java.lang.String, java.lang.Long, j.a.a.a.a0)',
#   'virtual long java.lang.Long.longValue()',
#   'virtual boolean j.a.a.a.n2.h.m0$a.a(j.a.a.a.j.a.e.b)',
#   'static java.lang.Boolean java.lang.Boolean.valueOf(boolean)',
#   'static boolean j.a.a.a.b2.e.h.a(java.lang.Boolean)',
#   'direct void j.a.b.b.h.f.<init>()',
#   'virtual void j.a.b.b.h.f.a(boolean)',
#   'direct/range void j.a.a.a.n2.h.p0.j1$e$a$a.<init>(long, j.a.a.a.b2.d.a, j.a.b.b.h.f, java.io.File, boolean)',
#   'interface boolean java.util.Collection.add(java.lang.Object)',
#   'direct void j.a.a.a.n2.h.p0.j1$e$a.<init>(java.lang.String, java.util.List)',
#   'virtual void j.a.a.a.n2.h.p0.j1.a(j.a.a.a.n2.h.p0.j1$e)',
#   'static boolean j.a.a.a.j.u.b.h.c()',
#   'static boolean com.linecorp.square.chat.SquareChatUtils.a(java.lang.String)',
#   'static void j.a.a.a.j.u.b.h.a(j.a.a.a.k.d, boolean, j.a.a.a.h.u, j.a.a.a.n2.h.e0)',
#   'direct void j.a.a.a.n2.h.p0.s3.<init>(j.a.a.a.k.d, j.a.a.a.h.u, boolean, j.a.a.a.n2.h.e0)',
#   'static boolean j.a.a.a.n2.h.j.B()',
#   'virtual void j.a.a.a.n2.h.j.b(j.a.a.a.n2.h.p0.s3)',
#   'static j.a.a.a.n2.h.g0 j.a.a.a.n2.h.g0.a()',
#   'interface void java.util.concurrent.Executor.execute(java.lang.Runnable)',
#   'interface void j.a.a.a.n2.h.i0$a.a(j.a.a.a.h.u)',
#   'interface void j.a.a.a.n2.h.i0$a.a(java.lang.Exception)',
#   'static java.lang.StringBuilder k.d.a.a.a.d(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(long)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(char)',
#   'virtual java.lang.String java.lang.StringBuilder.toString()',
#   'virtual java.lang.String java.lang.Object.toString()',
#   'direct void java.lang.IllegalStateException.<init>(java.lang.String)',
#   'direct void h2.i.<init>()'],
#  [])

# %%
getClazzConstStr(basePackageDict, "j.a.a.a.n2.h.l0$d")
# Out:
# class found!!!!
# 0: , is360Image=
# 1: Image(uri=
# 2: , relation=
# 3: , shouldSendOriginalImage=
# 4: , targetChatId=
# 5: )

# %%
printClazzMethodIdenti(basePackageDict,"j.a.a.a.b2.e.h")
# Out:
# 0: b(java.lang.Object)
# 1: a(android.content.Context,android.view.View)
# 2: a(int,int,int,int)
# 3: k(java.lang.Object[])
# 4: d(android.content.Context,java.lang.String)
# 5: a(java.lang.String,boolean)
# 6: a(android.content.Context,java.lang.String)
# 7: e(android.content.Context,java.lang.String)
# 8: a(android.app.Activity,java.lang.Throwable)
# 9: a(android.webkit.WebView,java.lang.String)
# 10: a(j.a.e.a.b.be)
# 11: a(org.json.JSONObject,java.lang.String)
# 12: c(java.lang.Object[])
# 13: c()
# 14: e(j.a.a.a.l2.o.a)
# 15: b(java.lang.Object[],java.lang.Object)
# 16: h()
# 17: t()
# 18: b(android.content.Context,java.lang.String)
# 19: k()
# 20: j(java.lang.Object[])
# 21: a(java.lang.String,long,android.net.Uri,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,boolean,java.util.Map,j.a.a.a.b2.d.d,j.a.a.a.b2.e.n$a,java.lang.String,java.lang.Class)
# 22: g(java.lang.Object[])
# 23: a(java.lang.String,j.a.a.a.b2.e.s,java.util.Map)
# 24: a(java.util.Map,h2.j0.b.l)
# 25: a(java.lang.Object[],int)
# 26: c(android.content.Context)
# 27: f(j.a.a.a.l2.o.a)
# 28: a(java.lang.String,j.a.a.a.b2.d.b,java.util.Map)
# 29: a(short[],short)
# 30: a(java.lang.String,java.lang.String,j.a.a.a.b2.d.a,java.util.Map)
# 31: a(android.graphics.Bitmap,java.io.File)
# 32: a(android.widget.TextView,java.lang.CharSequence)
# 33: e(org.json.JSONObject,java.lang.String)
# 34: a(android.text.Spanned)
# 35: b(android.webkit.WebView,java.lang.String)
# 36: a(android.content.Context,java.lang.Throwable,android.os.Handler,boolean)
# 37: a(boolean,java.lang.String,long)
# 38: a(j.a.a.a.l2.o.e)
# 39: a(android.app.Activity,int,h2.j0.b.l,int)
# 40: d(long)
# 41: c(long,long)
# 42: a(java.lang.Object[],java.lang.CharSequence,java.lang.CharSequence,java.lang.CharSequence,int,java.lang.CharSequence,h2.j0.b.l,int)
# 43: b(java.lang.CharSequence[])
# 44: f(long)
# 45: b(org.apache.http.HttpResponse)
# 46: a(android.database.Cursor,int)
# 47: b(android.app.Activity,int)
# 48: a(android.util.AttributeSet,android.content.Context,int[],int,int,h2.j0.b.l,int)
# 49: b(long[])
# 50: a(java.lang.String,long,java.io.File,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.d.d)
# 51: a(android.content.Context,long)
# 52: m(java.lang.Object[])
# 53: a(android.widget.ImageView,androidx.lifecycle.LiveData,v5.r.m,h2.j0.b.l)
# 54: a(java.lang.Object[],java.lang.Object[])
# 55: b(java.util.Calendar)
# 56: a(java.io.InputStream,java.io.OutputStream,long,long,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,boolean)
# 57: c(java.util.Map)
# 58: a(android.content.Context,android.graphics.Bitmap,java.lang.String)
# 59: a(java.io.InputStream,int,j.a.a.a.l2.p.c,j.a.a.a.l2.p.b)
# 60: e()
# 61: a(java.lang.String,int)
# 62: a(java.lang.String,boolean,j.a.a.a.b2.e.n$a,java.util.Map)
# 63: b(java.lang.String)
# 64: a(long[])
# 65: f()
# 66: a(java.lang.Object[],java.util.Collection)
# 67: e(long)
# 68: d()
# 69: c(j.a.a.a.l2.o.a)
# 70: a(java.io.InputStream)
# 71: a(java.util.Collection,java.lang.Object[])
# 72: a(org.json.JSONObject,java.lang.String,int)
# 73: a(j.a.e.a.b.be,long,java.lang.String,java.lang.String,java.lang.String,j.a.a.a.h.e,j.a.a.a.j.a.e.b,j.a.a.a.k.t.b,boolean,boolean,boolean)
# 74: b(java.lang.String,java.util.Map)
# 75: c(java.lang.String,java.lang.String,j.a.a.a.b2.d.a,java.util.Map)
# 76: a(java.util.Collection,java.lang.Iterable)
# 77: b(android.app.Activity)
# 78: a(android.view.View,j.a.a.a.t2.j1.a)
# 79: a(int)
# 80: a(android.graphics.Bitmap,android.graphics.Bitmap,int)
# 81: c(java.util.Calendar)
# 82: a(java.lang.Object[],java.lang.Object)
# 83: a(android.database.sqlite.SQLiteDatabase,java.lang.String,java.lang.String[],java.lang.String,java.lang.String[],java.lang.String,java.lang.String,java.lang.String,java.lang.String,int)
# 84: b(android.content.Context,android.view.View)
# 85: b(android.content.Context,long)
# 86: h(java.lang.Object[])
# 87: c(android.content.Context,j.a.a.a.t2.o,long,long)
# 88: a(java.lang.Object[])
# 89: a(java.lang.String,long,long,long)
# 90: n()
# 91: b(h2.j0.b.a)
# 92: a(java.util.Map)
# 93: a(android.view.View)
# 94: a(int,int,int,int,long)
# 95: e(java.lang.String)
# 96: b(java.lang.String,java.io.InputStream,long,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.e.n$a,java.lang.String)
# 97: d(java.util.Map)
# 98: a(char,java.lang.CharSequence[])
# 99: a(java.lang.String,java.io.InputStream,long,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.e.n$a,java.lang.String)
# 100: a(java.lang.String,java.lang.Long,j.a.a.a.a0)
# 101: b(int[],int)
# 102: a(java.lang.Iterable,java.lang.Class)
# 103: d(int)
# 104: b(j.a.a.a.l2.o.a)
# 105: q()
# 106: a(java.util.Collection)
# 107: c(android.database.Cursor,java.lang.String)
# 108: l(java.lang.Object[])
# 109: a(java.lang.String,java.io.InputStream,long,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.e.n$a)
# 110: c(org.json.JSONObject,java.lang.String)
# 111: a(java.lang.String)
# 112: d(j.a.a.a.l2.o.a)
# 113: a(java.lang.Object,java.lang.Object)
# 114: a(android.database.Cursor,h2.j0.b.l)
# 115: a(h2.k)
# 116: a(java.util.List)
# 117: a(android.app.Activity,j.a.a.a.t2.e)
# 118: a(android.database.Cursor,java.lang.String)
# 119: b(android.content.Context,j.a.a.a.t2.o,long,long)
# 120: a(android.text.Spanned,java.lang.Object)
# 121: a(java.lang.String,j.a.a.a.b2.e.n$a,j.a.a.a.b2.e.n$a,j.a.a.a.b2.e.s$b)
# 122: a(j.a.a.a.l.w.y)
# 123: a(java.lang.Boolean)
# 124: a(android.database.Cursor,java.lang.String,int,int)
# 125: b(java.util.List)
# 126: a(java.lang.String,java.util.Map)
# 127: a(java.lang.Iterable,j.a.a.a.t2.q1.a)
# 128: a(java.lang.Iterable,java.lang.Iterable)
# 129: b(android.database.Cursor)
# 130: a(j.a.a.a.l2.o.a)
# 131: f(java.lang.Object[])
# 132: b(android.view.View)
# 133: b(android.database.Cursor,java.lang.String)
# 134: a(org.json.JSONObject,java.lang.String,long)
# 135: a(byte[],byte)
# 136: a(long,java.util.TimeZone,java.util.Locale)
# 137: a(android.text.Editable,h2.m0.e,java.lang.CharSequence)
# 138: a(j.a.a.a.l2.p.b)
# 139: c(android.content.Context,java.lang.String)
# 140: a(android.database.Cursor,java.lang.String,java.lang.String,int)
# 141: a(android.database.Cursor,java.lang.String,java.lang.String)
# 142: a(java.lang.Object)
# 143: a(android.app.Activity)
# 144: a(java.lang.Throwable)
# 145: a(java.lang.String,long,android.net.Uri,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.d.d)
# 146: g(java.lang.String)
# 147: a(java.util.List,int)
# 148: f(java.lang.String)
# 149: a(android.database.Cursor,java.lang.String,long,int)
# 150: b(java.lang.Object[])
# 151: a(j.a.a.a.h.e,j.a.a.a.k.t.b)
# 152: a(java.lang.Iterable)
# 153: a(android.database.Cursor,j.a.a.a.d.a.j4,java.lang.String)
# 154: a(long[],long)
# 155: a(android.content.Context,java.lang.String,java.lang.String,java.lang.String,java.lang.String,java.util.List)
# 156: b(long)
# 157: a(android.database.Cursor,j.a.a.a.d.a.j4,j.a.a.a.b2.d.a$b,android.content.Context,long,int,int)
# 158: d(java.lang.String)
# 159: a(java.util.List,h2.j0.b.l)
# 160: r()
# 161: a(android.app.Activity,int)
# 162: b(org.json.JSONObject,java.lang.String)
# 163: c(android.content.Context,android.net.Uri)
# 164: a(int[],int)
# 165: a(j.a.e.a.b.b7)
# 166: a(android.content.Context,android.os.IBinder)
# 167: a(long,java.util.TimeZone,java.util.Locale,int)
# 168: h(java.lang.String)
# 169: a(java.util.Map,j.a.a.a.b2.d.d)
# 170: a(java.lang.String,long,android.net.Uri,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.d.d,j.a.a.a.b2.e.n$a,java.lang.String,java.lang.Class)
# 171: b(java.util.Map)
# 172: a(java.lang.String,boolean,boolean,j.a.a.a.b2.e.n$a,java.util.Map)
# 173: b(long[],long)
# 174: a(java.lang.String,long,android.net.Uri,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map)
# 175: c(java.lang.String)
# 176: b(android.net.Uri)
# 177: a(java.lang.String,int,int)
# 178: g()
# 179: a(java.lang.Iterable,h2.j0.b.l,boolean)
# 180: a(j.a.a.a.b2.e.n,java.util.Map,boolean)
# 181: b(java.util.Collection,java.lang.Object[])
# 182: a(java.io.InputStream,java.io.OutputStream)
# 183: a(android.database.Cursor)
# 184: a(android.database.Cursor,j.a.a.a.d.a.j4,j.a.a.a.b2.d.a$b,long)
# 185: p()
# 186: a(j.a.a.a.j.t.b.a,j.a.a.a.n2.e$c)
# 187: a(androidx.recyclerview.widget.RecyclerView,boolean,int)
# 188: a(org.apache.http.HttpResponse)
# 189: a(double,double)
# 190: d(java.util.Calendar)
# 191: a(java.lang.String,java.lang.Object)
# 192: l()
# 193: a(java.io.File)
# 194: c(long)
# 195: a(java.lang.String,long,java.io.File,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map)
# 196: a(jp.naver.line.android.LineApplication,j.a.a.a.k.d,j.a.a.a.v0.n,j.a.a.a.n2.h.n,java.lang.String,j.a.e.a.b.be,long,java.lang.String,java.lang.String,java.lang.String,j.a.a.a.j.a.e.b,boolean)
# 197: a(java.lang.Throwable,java.lang.String)
# 198: a(long,long)
# 199: a(android.util.SparseArray,int,java.lang.Object)
# 200: a(java.lang.String,j.a.a.a.b2.e.n$a,j.a.a.a.b2.e.n$a)
# 201: a(android.content.Context)
# 202: a(char[])
# 203: b(java.lang.String,j.a.a.a.b2.e.s,java.util.Map)
# 204: e(java.lang.Object[])
# 205: c(int)
# 206: a(android.app.Activity,int,h2.j0.b.l)
# 207: b(java.lang.String,int,int)
# 208: a(android.view.LayoutInflater)
# 209: a(android.database.Cursor,java.lang.String,long)
# 210: a(android.database.Cursor,java.lang.String,int)
# 211: o()
# 212: a(long,java.lang.String)
# 213: b(long,long)
# 214: a(v5.f.g,java.lang.Object,java.lang.Object)
# 215: a(android.content.pm.PackageManager,java.lang.String)
# 216: i()
# 217: b(android.content.Context)
# 218: a(char[],java.lang.CharSequence,java.lang.CharSequence,java.lang.CharSequence,int,java.lang.CharSequence,h2.j0.b.l)
# 219: a(java.lang.String,java.util.Map,j.a.a.a.l2.p.c,j.a.a.a.l2.p.b)
# 220: a(java.util.Date,java.util.TimeZone,java.util.Locale,int)
# 221: a(android.content.Context,android.net.Uri)
# 222: d(java.lang.Object[])
# 223: a(org.json.JSONObject,java.lang.String,java.lang.Long)
# 224: a(int,int)
# 225: a(java.lang.String,long,android.net.Uri,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.d.d,java.lang.String)
# 226: a(android.content.Context,android.view.View,int)
# 227: a(java.lang.Iterable,int)
# 228: b()
# 229: c(android.content.Context,long)
# 230: a(java.util.Calendar)
# 231: a(java.lang.Object[],java.util.Comparator)
# 232: c(int[],int)
# 233: a(java.lang.String,boolean,boolean,j.a.a.a.b2.e.n$a)
# 234: b(int)
# 235: s()
# 236: a(int[])
# 237: a(java.lang.String,java.util.Map,j.a.a.a.b2.e.n$a)
# 238: d(org.json.JSONObject,java.lang.String)
# 239: d(android.database.Cursor,java.lang.String)
# 240: j()
# 241: a(long)
# 242: a(java.util.Collection,java.util.Iterator)
# 243: a(org.json.JSONObject,java.lang.String,java.lang.String)
# 244: a(java.util.TimeZone,java.util.Locale,int)
# 245: a(android.content.Context,j.a.a.a.t2.o,long,long)
# 246: a(java.lang.String,boolean,j.a.a.a.b2.e.n$a)
# 247: a(h2.h,h2.j0.b.a)
# 248: a(android.net.Uri)
# 249: b(java.lang.String,long,java.io.File,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.d.d)
# 250: a(java.lang.Object[],h2.j0.b.l)
# 251: a(java.lang.CharSequence[])
# 252: a(org.json.JSONArray)
# 253: a(h2.j0.b.a)
# 254: i(java.lang.Object[])
# 255: a(android.content.Context,java.lang.String,java.lang.String)
# 256: d(android.content.Context)
# 257: c(java.util.List)
# 258: a(android.content.Context,android.graphics.Bitmap)
# 259: a(android.content.Context,int)
# 260: a(char[],char)
# 261: m()
# 262: b(java.lang.String,java.lang.String,j.a.a.a.b2.d.a,java.util.Map)
# 263: a(j.a.a.a.b2.e.h$b)
# 264: a(android.app.Activity,int,java.lang.String,java.io.File)
# 265: a(android.content.Context,java.lang.String,java.io.File)
# 266: b(android.content.Context,android.net.Uri)
# 267: a()
# dict_keys(['b(java.lang.Object)', 'a(android.content.Context,android.view.View)', 'a(int,int,int,int)', 'k(java.lang.Object[])', 'd(android.content.Context,java.lang.String)', 'a(java.lang.String,boolean)', 'a(android.content.Context,java.lang.String)', 'e(android.content.Context,java.lang.String)', 'a(android.app.Activity,java.lang.Throwable)', 'a(android.webkit.WebView,java.lang.String)', 'a(j.a.e.a.b.be)', 'a(org.json.JSONObject,java.lang.String)', 'c(java.lang.Object[])', 'c()', 'e(j.a.a.a.l2.o.a)', 'b(java.lang.Object[],java.lang.Object)', 'h()', 't()', 'b(android.content.Context,java.lang.String)', 'k()', 'j(java.lang.Object[])', 'a(java.lang.String,long,android.net.Uri,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,boolean,java.util.Map,j.a.a.a.b2.d.d,j.a.a.a.b2.e.n$a,java.lang.String,java.lang.Class)', 'g(java.lang.Object[])', 'a(java.lang.String,j.a.a.a.b2.e.s,java.util.Map)', 'a(java.util.Map,h2.j0.b.l)', 'a(java.lang.Object[],int)', 'c(android.content.Context)', 'f(j.a.a.a.l2.o.a)', 'a(java.lang.String,j.a.a.a.b2.d.b,java.util.Map)', 'a(short[],short)', 'a(java.lang.String,java.lang.String,j.a.a.a.b2.d.a,java.util.Map)', 'a(android.graphics.Bitmap,java.io.File)', 'a(android.widget.TextView,java.lang.CharSequence)', 'e(org.json.JSONObject,java.lang.String)', 'a(android.text.Spanned)', 'b(android.webkit.WebView,java.lang.String)', 'a(android.content.Context,java.lang.Throwable,android.os.Handler,boolean)', 'a(boolean,java.lang.String,long)', 'a(j.a.a.a.l2.o.e)', 'a(android.app.Activity,int,h2.j0.b.l,int)', 'd(long)', 'c(long,long)', 'a(java.lang.Object[],java.lang.CharSequence,java.lang.CharSequence,java.lang.CharSequence,int,java.lang.CharSequence,h2.j0.b.l,int)', 'b(java.lang.CharSequence[])', 'f(long)', 'b(org.apache.http.HttpResponse)', 'a(android.database.Cursor,int)', 'b(android.app.Activity,int)', 'a(android.util.AttributeSet,android.content.Context,int[],int,int,h2.j0.b.l,int)', 'b(long[])', 'a(java.lang.String,long,java.io.File,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.d.d)', 'a(android.content.Context,long)', 'm(java.lang.Object[])', 'a(android.widget.ImageView,androidx.lifecycle.LiveData,v5.r.m,h2.j0.b.l)', 'a(java.lang.Object[],java.lang.Object[])', 'b(java.util.Calendar)', 'a(java.io.InputStream,java.io.OutputStream,long,long,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,boolean)', 'c(java.util.Map)', 'a(android.content.Context,android.graphics.Bitmap,java.lang.String)', 'a(java.io.InputStream,int,j.a.a.a.l2.p.c,j.a.a.a.l2.p.b)', 'e()', 'a(java.lang.String,int)', 'a(java.lang.String,boolean,j.a.a.a.b2.e.n$a,java.util.Map)', 'b(java.lang.String)', 'a(long[])', 'f()', 'a(java.lang.Object[],java.util.Collection)', 'e(long)', 'd()', 'c(j.a.a.a.l2.o.a)', 'a(java.io.InputStream)', 'a(java.util.Collection,java.lang.Object[])', 'a(org.json.JSONObject,java.lang.String,int)', 'a(j.a.e.a.b.be,long,java.lang.String,java.lang.String,java.lang.String,j.a.a.a.h.e,j.a.a.a.j.a.e.b,j.a.a.a.k.t.b,boolean,boolean,boolean)', 'b(java.lang.String,java.util.Map)', 'c(java.lang.String,java.lang.String,j.a.a.a.b2.d.a,java.util.Map)', 'a(java.util.Collection,java.lang.Iterable)', 'b(android.app.Activity)', 'a(android.view.View,j.a.a.a.t2.j1.a)', 'a(int)', 'a(android.graphics.Bitmap,android.graphics.Bitmap,int)', 'c(java.util.Calendar)', 'a(java.lang.Object[],java.lang.Object)', 'a(android.database.sqlite.SQLiteDatabase,java.lang.String,java.lang.String[],java.lang.String,java.lang.String[],java.lang.String,java.lang.String,java.lang.String,java.lang.String,int)', 'b(android.content.Context,android.view.View)', 'b(android.content.Context,long)', 'h(java.lang.Object[])', 'c(android.content.Context,j.a.a.a.t2.o,long,long)', 'a(java.lang.Object[])', 'a(java.lang.String,long,long,long)', 'n()', 'b(h2.j0.b.a)', 'a(java.util.Map)', 'a(android.view.View)', 'a(int,int,int,int,long)', 'e(java.lang.String)', 'b(java.lang.String,java.io.InputStream,long,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,java.util.Map,j.a.a.a.b2.e.n$a,java ...

# %%
printMethodFeature(basePackageDict,"j.a.a.a.b2.e.h.a(java.lang.String,long,android.net.Uri,j.a.a.a.b2.e.s,j.a.a.a.b2.e.h$c,j.a.a.a.b2.e.h$b,boolean,java.util.Map,j.a.a.a.b2.d.d,j.a.a.a.b2.e.n$a,java.lang.String,java.lang.Class)",set(),False)
# Out:
# 0: static j.a.a.a.b2.e.n j.a.a.a.b2.e.h.a(java.lang.String, boolean, j.a.a.a.b2.e.n$a)
# 1: interface java.net.URL j.a.a.a.b2.e.n.f()
# 2: virtual java.lang.String java.net.URL.toString()
# 3: interface void j.a.a.a.b2.e.n.a(boolean)
# 4: virtual/range java.lang.String android.net.Uri.getPath()
# 5: direct void java.io.File.<init>(java.lang.String)
# 6: virtual/range j.a.a.a.b2.e.s$b j.a.a.a.b2.e.s.b()
# 7: virtual boolean java.io.File.exists()
# 8: virtual java.lang.String java.io.File.getAbsolutePath()
# 9: direct void android.media.MediaMetadataRetriever.<init>()
# 10: virtual void android.media.MediaMetadataRetriever.setDataSource(java.lang.String)
# 11: virtual java.lang.String android.media.MediaMetadataRetriever.extractMetadata(int)
# 12: virtual boolean java.lang.String.equals(java.lang.Object)
# 13: virtual boolean java.lang.String.equals(java.lang.Object)
# 14: static java.lang.String java.lang.String.valueOf(int)
# 15: interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)
# 16: static android.app.Application j.a.a.a.l.f.a()
# 17: interface void j.a.a.a.b2.e.n.b(int)
# 18: interface void j.a.a.a.b2.e.n.c(boolean)
# 19: interface void j.a.a.a.b2.e.n.a(java.lang.String)
# 20: interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)
# 21: interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)
# 22: interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)
# 23: interface/range java.util.Set java.util.Map.entrySet()
# 24: interface java.util.Iterator java.util.Set.iterator()
# 25: interface boolean java.util.Iterator.hasNext()
# 26: interface java.lang.Object java.util.Iterator.next()
# 27: interface java.lang.Object java.util.Map$Entry.getKey()
# 28: interface java.lang.Object java.util.Map$Entry.getValue()
# 29: interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)
# 30: interface java.lang.Object java.util.Map$Entry.getKey()
# 31: virtual boolean java.lang.String.equalsIgnoreCase(java.lang.String)
# 32: virtual boolean java.lang.String.equalsIgnoreCase(java.lang.String)
# 33: virtual boolean java.lang.String.equalsIgnoreCase(java.lang.String)
# 34: static java.lang.String j.a.a.a.l.j.c.d()
# 35: interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)
# 36: static java.lang.String j.a.a.a.e2.d.f()
# 37: interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)
# 38: static java.lang.String j.a.a.a.e2.d.i()
# 39: interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)
# 40: static java.lang.String j.a.a.a.b2.e.h.m()
# 41: static boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)
# 42: interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)
# 43: static/range boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)
# 44: static byte[] j.a.a.a.b2.e.k.a()
# 45: direct void java.lang.String.<init>(byte[])
# 46: static void j.a.a.a.b2.e.k.a(java.io.File, long, j.a.a.a.b2.e.s)
# 47: direct void java.lang.StringBuilder.<init>()
# 48: static boolean y5.c.r0.a.a(java.util.Map)
# 49: static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)
# 50: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 51: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 52: static/range boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)
# 53: virtual/range org.json.JSONObject j.a.a.a.b2.e.s.e()
# 54: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.Object)
# 55: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 56: interface java.util.Set java.util.Map.entrySet()
# 57: interface java.util.Iterator java.util.Set.iterator()
# 58: interface boolean java.util.Iterator.hasNext()
# 59: interface java.lang.Object java.util.Iterator.next()
# 60: static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)
# 61: interface java.lang.Object java.util.Map$Entry.getKey()
# 62: static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)
# 63: interface java.lang.Object java.util.Map$Entry.getValue()
# 64: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.Object)
# 65: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 66: static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)
# 67: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 68: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 69: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 70: virtual java.lang.String java.io.File.getName()
# 71: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 72: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 73: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 74: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 75: virtual/range java.lang.String j.a.a.a.b2.e.s.a()
# 76: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 77: static java.lang.String k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String)
# 78: static java.lang.String k.d.a.a.a.b(java.lang.String, java.lang.String, java.lang.String, java.lang.String, java.lang.String)
# 79: interface void j.a.a.a.b2.e.n.a(java.lang.String, java.lang.String, java.lang.String)
# 80: static void j.a.a.a.b2.e.k.a(java.io.File, long, j.a.a.a.b2.e.s)
# 81: virtual/range org.json.JSONObject j.a.a.a.b2.e.s.e()
# 82: virtual java.lang.String org.json.JSONObject.toString()
# 83: virtual byte[] java.lang.String.getBytes()
# 84: static java.lang.String j.a.a.a.k.s.a.x.a(byte[])
# 85: interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)
# 86: virtual/range java.lang.String j.a.a.a.b2.e.s.a()
# 87: interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)
# 88: interface void j.a.a.a.b2.e.n.a(java.io.File, long)
# 89: interface int j.a.a.a.b2.e.n.b(j.a.a.a.b2.e.h$c, j.a.a.a.b2.e.h$b)
# 90: interface java.util.Map j.a.a.a.b2.e.n.getResponseHeaders()
# 91: static void j.a.a.a.b2.e.h.a(java.util.Map, j.a.a.a.b2.d.d)
# 92: interface boolean java.util.Map.containsKey(java.lang.Object)
# 93: interface java.lang.Object java.util.Map.get(java.lang.Object)
# 94: static int j.a.a.a.b2.e.h.a(java.lang.String, int)
# 95: interface java.lang.String j.a.a.a.b2.e.n.c()
# 96: interface void j.a.a.a.b2.e.n.a()
# 97: static java.lang.Integer java.lang.Integer.valueOf(int)
# 98: static java.lang.Integer java.lang.Integer.valueOf(int)
# 99: direct void android.util.Pair.<init>(java.lang.Object, java.lang.Object)
# 100: static boolean j.a.a.a.l.j.c.a()
# 101: direct void java.lang.StringBuilder.<init>()
# 102: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 103: virtual java.lang.StringBuilder java.lang.StringBuilder.append(int)
# 104: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 105: virtual java.lang.String java.lang.StringBuilder.toString()
# 106: direct void j.a.a.a.b2.e.u.<init>(java.lang.String)
# 107: direct void java.lang.StringBuilder.<init>()
# 108: virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)
# 109: virtual java.lang.StringBuilder java.lang.StringBuilder.append(int)
# 110: virtual java.lang.String java.lang.StringBuilder.toString()
# 111: direct void j.a.a.a.b2.e.v.<init>(java.lang.String, int, java.util.Map)
# 112: virtual int j.a.a.a.o0.n.a()
# 113: static j.a.a.a.o0.c$a j.a.a.a.o0.c.a(int)
# 114: virtual int j.a.a.a.o0.n.b()
# 115: virtual void android.util.SparseArray.put(int, java.lang.Object)
# 116: virtual int j.a.a.a.o0.n.b()
# 117: virtual j.a.a.a.o0.c$a j.a.a.a.o0.c$a.a(int, java.lang.Throwable)
# 118: virtual void j.a.a.a.o0.c$a.a()
# 119: interface void j.a.a.a.b2.e.n.a()
# ('public static java.lang.Object c.c.c.c.c.c.c.a(java.lang.String, long, android.net.Uri, j.a.a.a.b2.e.s, j.a.a.a.b2.e.h$c, j.a.a.a.b2.e.h$b, boolean, java.util.Map, j.a.a.a.b2.d.d, j.a.a.a.b2.e.n$a, java.lang.String, java.lang.Class)',
#  ['errorCode',
#   'Line SnapMovie',
#   '\\',
#   'scenetime',
#   'POST',
#   'accept',
#   '*/*',
#   'connection',
#   'Keep-Alive',
#   'cache-control',
#   'no-cache',
#   'User-Agent',
#   'X-Line-Application',
#   'X-Line-ChannelToken',
#   'X-Line-Access',
#   'X-Line-Carrier',
#   '\\',
#   'Content-Disposition: form-data; name=\\',
#   '\\r\\n',
#   '--',
#   'Content-Disposition: form-data; name=\\',
#   '\\',
#   ' filename=\\',
#   'Content-Type: ',
#   'x-obs-params',
#   'content-type',
#   'ResponseCode=',
#   ' UNAUTHORIZED.',
#   'ResponseCode is not CREATED(201). responseCode=',
#   'OBSU::uploadUseSocket::1'],
#  ['static j.a.a.a.b2.e.n j.a.a.a.b2.e.h.a(java.lang.String, boolean, j.a.a.a.b2.e.n$a)',
#   'interface java.net.URL j.a.a.a.b2.e.n.f()',
#   'virtual java.lang.String java.net.URL.toString()',
#   'interface void j.a.a.a.b2.e.n.a(boolean)',
#   'virtual/range java.lang.String android.net.Uri.getPath()',
#   'direct void java.io.File.<init>(java.lang.String)',
#   'virtual/range j.a.a.a.b2.e.s$b j.a.a.a.b2.e.s.b()',
#   'virtual boolean java.io.File.exists()',
#   'virtual java.lang.String java.io.File.getAbsolutePath()',
#   'direct void android.media.MediaMetadataRetriever.<init>()',
#   'virtual void android.media.MediaMetadataRetriever.setDataSource(java.lang.String)',
#   'virtual java.lang.String android.media.MediaMetadataRetriever.extractMetadata(int)',
#   'virtual boolean java.lang.String.equals(java.lang.Object)',
#   'virtual boolean java.lang.String.equals(java.lang.Object)',
#   'static java.lang.String java.lang.String.valueOf(int)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static android.app.Application j.a.a.a.l.f.a()',
#   'interface void j.a.a.a.b2.e.n.b(int)',
#   'interface void j.a.a.a.b2.e.n.c(boolean)',
#   'interface void j.a.a.a.b2.e.n.a(java.lang.String)',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'interface/range java.util.Set java.util.Map.entrySet()',
#   'interface java.util.Iterator java.util.Set.iterator()',
#   'interface boolean java.util.Iterator.hasNext()',
#   'interface java.lang.Object java.util.Iterator.next()',
#   'interface java.lang.Object java.util.Map$Entry.getKey()',
#   'interface java.lang.Object java.util.Map$Entry.getValue()',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'interface java.lang.Object java.util.Map$Entry.getKey()',
#   'virtual boolean java.lang.String.equalsIgnoreCase(java.lang.String)',
#   'virtual boolean java.lang.String.equalsIgnoreCase(java.lang.String)',
#   'virtual boolean java.lang.String.equalsIgnoreCase(java.lang.String)',
#   'static java.lang.String j.a.a.a.l.j.c.d()',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'static java.lang.String j.a.a.a.e2.d.f()',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'static java.lang.String j.a.a.a.e2.d.i()',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'static java.lang.String j.a.a.a.b2.e.h.m()',
#   'static boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'static/range boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)',
#   'static byte[] j.a.a.a.b2.e.k.a()',
#   'direct void java.lang.String.<init>(byte[])',
#   'static void j.a.a.a.b2.e.k.a(java.io.File, long, j.a.a.a.b2.e.s)',
#   'direct void java.lang.StringBuilder.<init>()',
#   'static boolean y5.c.r0.a.a(java.util.Map)',
#   'static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'static/range boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)',
#   'virtual/range org.json.JSONObject j.a.a.a.b2.e.s.e()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.Object)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'interface java.util.Set java.util.Map.entrySet()',
#   'interface java.util.Iterator java.util.Set.iterator()',
#   'interface boolean java.util.Iterator.hasNext()',
#   'interface java.lang.Object java.util.Iterator.next()',
#   'static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)',
#   'interface java.lang.Object java.util.Map$Entry.getKey()',
#   'static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)',
#   'interface java.lang.Object java.util.Map$Entry.getValue()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.Object)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.String java.io.File.getName()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual/range java.lang.String j.a.a.a.b2.e.s.a()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'static java.lang.String k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String)',
#   'static java.lang.String k.d.a.a.a.b(java.lang.String, java.lang.String, java.lang.String, java.lang.String, java.lang.String)',
#   'interface void j.a.a.a.b2.e.n.a(java.lang.String, java.lang.String, java.lang.String)',
#   'static void j.a.a.a.b2.e.k.a(java.io.File, long, j.a.a.a.b2.e.s)',
#   'virtual/range org.json.JSONObject j.a.a.a.b2.e.s.e()',
#   'virtual java.lang.String org.json.JSONObject.toString()',
#   'virtual byte[] java.lang.String.getBytes()',
#   'static java.lang.String j.a.a.a.k.s.a.x.a(byte[])',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'virtual/range java.lang.String j.a.a.a.b2.e.s.a()',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'interface void j.a.a.a.b2.e.n.a(java.io.File, long)',
#   'interface int j.a.a.a.b2.e.n.b(j.a.a.a.b2.e.h$c, j.a.a.a.b2.e.h$b)',
#   'interface java.util.Map j.a.a.a.b2.e.n.getResponseHeaders()',
#   'static void j.a.a.a.b2.e.h.a(java.util.Map, j.a.a.a.b2.d.d)',
#   'interface boolean java.util.Map.containsKey(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.get(java.lang.Object)',
#   'static int j.a.a.a.b2.e.h.a(java.lang.String, int)',
#   'interface java.lang.String j.a.a.a.b2.e.n.c()',
#   'interface void j.a.a.a.b2.e.n.a()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'direct void android.util.Pair.<init>(java.lang.Object, java.lang.Object)',
#   'static boolean j.a.a.a.l.j.c.a()',
#   'direct void java.lang.StringBuilder.<init>()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(int)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.String java.lang.StringBuilder.toString()',
#   'direct void j.a.a.a.b2.e.u.<init>(java.lang.String)',
#   'direct void java.lang.StringBuilder.<init>()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(int)',
#   'virtual java.lang.String java.lang.StringBuilder.toString()',
#   'direct void j.a.a.a.b2.e.v.<init>(java.lang.String, int, java.util.Map)',
#   'virtual int j.a.a.a.o0.n.a()',
#   'static j.a.a.a.o0.c$a j.a.a.a.o0.c.a(int)',
#   'virtual int j.a.a.a.o0.n.b()',
#   'virtual void android.util.SparseArray.put(int, java.lang.Object)',
#   'virtual int j.a.a.a.o0.n.b()',
#   'virtual j.a.a.a.o0.c$a j.a.a.a.o0.c$a.a(int, java.lang.Throwable)',
#   'virtual void j.a.a.a.o0.c$a.a()',
#   'interface void j.a.a.a.b2.e.n.a()'],
#  ['static j.a.a.a.b2.e.n j.a.a.a.b2.e.h.a(java.lang.String, boolean, j.a.a.a.b2.e.n$a)',
#   'interface java.net.URL j.a.a.a.b2.e.n.f()',
#   'virtual java.lang.String java.net.URL.toString()',
#   'interface void j.a.a.a.b2.e.n.a(boolean)',
#   'virtual/range java.lang.String android.net.Uri.getPath()',
#   'direct void java.io.File.<init>(java.lang.String)',
#   'virtual/range j.a.a.a.b2.e.s$b j.a.a.a.b2.e.s.b()',
#   'virtual boolean java.io.File.exists()',
#   'virtual java.lang.String java.io.File.getAbsolutePath()',
#   'direct void android.media.MediaMetadataRetriever.<init>()',
#   'virtual void android.media.MediaMetadataRetriever.setDataSource(java.lang.String)',
#   'virtual java.lang.String android.media.MediaMetadataRetriever.extractMetadata(int)',
#   'virtual boolean java.lang.String.equals(java.lang.Object)',
#   'virtual boolean java.lang.String.equals(java.lang.Object)',
#   'static java.lang.String java.lang.String.valueOf(int)',
#   'interface java.lang.Object java.util.Map.put(java.lang.Object, java.lang.Object)',
#   'static android.app.Application j.a.a.a.l.f.a()',
#   'interface void j.a.a.a.b2.e.n.b(int)',
#   'interface void j.a.a.a.b2.e.n.c(boolean)',
#   'interface void j.a.a.a.b2.e.n.a(java.lang.String)',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'interface/range java.util.Set java.util.Map.entrySet()',
#   'interface java.util.Iterator java.util.Set.iterator()',
#   'interface boolean java.util.Iterator.hasNext()',
#   'interface java.lang.Object java.util.Iterator.next()',
#   'interface java.lang.Object java.util.Map$Entry.getKey()',
#   'interface java.lang.Object java.util.Map$Entry.getValue()',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'interface java.lang.Object java.util.Map$Entry.getKey()',
#   'virtual boolean java.lang.String.equalsIgnoreCase(java.lang.String)',
#   'virtual boolean java.lang.String.equalsIgnoreCase(java.lang.String)',
#   'virtual boolean java.lang.String.equalsIgnoreCase(java.lang.String)',
#   'static java.lang.String j.a.a.a.l.j.c.d()',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'static java.lang.String j.a.a.a.e2.d.f()',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'static java.lang.String j.a.a.a.e2.d.i()',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'static java.lang.String j.a.a.a.b2.e.h.m()',
#   'static boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'static/range boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)',
#   'static byte[] j.a.a.a.b2.e.k.a()',
#   'direct void java.lang.String.<init>(byte[])',
#   'static void j.a.a.a.b2.e.k.a(java.io.File, long, j.a.a.a.b2.e.s)',
#   'direct void java.lang.StringBuilder.<init>()',
#   'static boolean y5.c.r0.a.a(java.util.Map)',
#   'static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'static/range boolean android.text.TextUtils.isEmpty(java.lang.CharSequence)',
#   'virtual/range org.json.JSONObject j.a.a.a.b2.e.s.e()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.Object)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'interface java.util.Set java.util.Map.entrySet()',
#   'interface java.util.Iterator java.util.Set.iterator()',
#   'interface boolean java.util.Iterator.hasNext()',
#   'interface java.lang.Object java.util.Iterator.next()',
#   'static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)',
#   'interface java.lang.Object java.util.Map$Entry.getKey()',
#   'static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)',
#   'interface java.lang.Object java.util.Map$Entry.getValue()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.Object)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'static void k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String, java.lang.String, java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.String java.io.File.getName()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual/range java.lang.String j.a.a.a.b2.e.s.a()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'static java.lang.String k.d.a.a.a.a(java.lang.StringBuilder, java.lang.String, java.lang.String)',
#   'static java.lang.String k.d.a.a.a.b(java.lang.String, java.lang.String, java.lang.String, java.lang.String, java.lang.String)',
#   'interface void j.a.a.a.b2.e.n.a(java.lang.String, java.lang.String, java.lang.String)',
#   'static void j.a.a.a.b2.e.k.a(java.io.File, long, j.a.a.a.b2.e.s)',
#   'virtual/range org.json.JSONObject j.a.a.a.b2.e.s.e()',
#   'virtual java.lang.String org.json.JSONObject.toString()',
#   'virtual byte[] java.lang.String.getBytes()',
#   'static java.lang.String j.a.a.a.k.s.a.x.a(byte[])',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'virtual/range java.lang.String j.a.a.a.b2.e.s.a()',
#   'interface void j.a.a.a.b2.e.n.setRequestProperty(java.lang.String, java.lang.String)',
#   'interface void j.a.a.a.b2.e.n.a(java.io.File, long)',
#   'interface int j.a.a.a.b2.e.n.b(j.a.a.a.b2.e.h$c, j.a.a.a.b2.e.h$b)',
#   'interface java.util.Map j.a.a.a.b2.e.n.getResponseHeaders()',
#   'static void j.a.a.a.b2.e.h.a(java.util.Map, j.a.a.a.b2.d.d)',
#   'interface boolean java.util.Map.containsKey(java.lang.Object)',
#   'interface java.lang.Object java.util.Map.get(java.lang.Object)',
#   'static int j.a.a.a.b2.e.h.a(java.lang.String, int)',
#   'interface java.lang.String j.a.a.a.b2.e.n.c()',
#   'interface void j.a.a.a.b2.e.n.a()',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'static java.lang.Integer java.lang.Integer.valueOf(int)',
#   'direct void android.util.Pair.<init>(java.lang.Object, java.lang.Object)',
#   'static boolean j.a.a.a.l.j.c.a()',
#   'direct void java.lang.StringBuilder.<init>()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(int)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.String java.lang.StringBuilder.toString()',
#   'direct void j.a.a.a.b2.e.u.<init>(java.lang.String)',
#   'direct void java.lang.StringBuilder.<init>()',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(java.lang.String)',
#   'virtual java.lang.StringBuilder java.lang.StringBuilder.append(int)',
#   'virtual java.lang.String java.lang.StringBuilder.toString()',
#   'direct void j.a.a.a.b2.e.v.<init>(java.lang.String, int, java.util.Map)',
#   'virtual int j.a.a.a.o0.n.a()',
#   'static j.a.a.a.o0.c$a j.a.a.a.o0.c.a(int)',
#   'virtual int j.a.a.a.o0.n.b()',
#   'virtual void android.util.SparseArray.put(int, java.lang.Object)',
#   'virtual int j.a.a.a.o0.n.b()',
#   'virtual j.a.a.a.o0.c$a j.a.a.a.o0.c$a.a(int, java.lang.Throwable)',
#   'virtual void j.a.a.a.o0.c$a.a()',
#   'interface void j.a.a.a.b2.e.n.a()'],
#  [])
